# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
# A primeira questão que eu preciso resolver é como abrir large files
# https://code.tutsplus.com/tutorials/quick-tip-how-to-read-extremely-large-text-files-using-python--cms-25992

# %%
input_file = open('../../data/b3/NEG_20191126.TXT','r')

# %%
line = input_file.readline()

# %%
type(line)
# Out:
# str

# %%
print(line)
# Out:
# 2019-11-26;AALR3                                             ;0000005000; 000000000019.000000;000000000000001600;13:29:02.595;1;2019-11-26;000861255168052;000000016094974;2;2019-11-26;000861255179066;000000016094975;1;0;00000107;00000008

# %%
for lines in range(500):
    line = input_file.readline()
    print(line)
# Out:
# 2019-11-26;AALR3                                             ;0000000010; 000000000019.470000;000000000000000100;10:00:00.000;1;2019-11-26;000861253407911;000000010766166;2;2019-11-26;000861253413206;000000010766167;2;0;00000386;00000308
#
# 2019-11-26;AALR3                                             ;0000000020; 000000000019.470000;000000000000000100;10:00:00.000;1;2019-11-26;000861253407911;000000010766169;2;2019-11-26;000861253416736;000000010766170;2;0;00000386;00000040
#
# 2019-11-26;AALR3                                             ;0000000030; 000000000019.470000;000000000000000100;10:00:00.000;1;2019-11-26;000861253408446;000000010766171;2;2019-11-26;000861253416737;000000010766172;2;0;00000003;00000040
#
# 2019-11-26;AALR3                                             ;0000000040; 000000000019.470000;000000000000000100;10:00:00.000;1;2019-11-26;000861253408446;000000010766173;2;2019-11-26;000861253417991;000000010766174;2;0;00000003;00000015
#
# ...
