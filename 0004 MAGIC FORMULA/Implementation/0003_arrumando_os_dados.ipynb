# %%
# O objetivo aqui vai ser arrumar os dados para backtest

# %%
import pandas as pd
import numpy as np

# %%
ta_ati = pd.read_excel('../../data/economatica_1/total_assets_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ta_can = pd.read_excel('../../data/economatica_1/total_assets_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
# ta.can = ta_can(["Jan-86", "Feb-86"]) # assim não precisaria de inplace
ta_can.drop(["Jan-86", "Feb-86"], inplace=True) # para ficar igual a index de ta_ati

# tudo sobre merging de dataframes
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
# checar se dois index são iguais
# https://www.geeksforgeeks.org/python-pandas-index-equals/
# ta_ati.index.equals(ta_can.index) # retorna falso pois cancelados começa em janeiro de 86 e ativos começa em jan
# tot_ass.loc["Jan-86"]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html
tot_ass = pd.concat([ta_ati,ta_can],axis=1,sort=False)
# len(ta_ati.columns)
# ta_can.shape

# %%
tickers = tot_ass.columns.str.extract('(.*)$')[0]
tot_ass.columns = tickers
# https://www.debuggex.com/cheatsheet/regex/python
# https://www.dataquest.io/blog/regex-cheatsheet/
on = tickers[tickers.str.contains('.\D3$')]
pn = tickers[tickers.str.contains('.\D4$')]
sto_tick = pd.concat([on, pn], ignore_index=True)
tot_ass = tot_ass[sto_tick]
tot_ass = tot_ass[tot_ass.index.str.contains("Mar|Jun|Sep|Dec")]
tot_ass.columns.name = "ticker"

# %%
tot_ass
# Out:
# ticker     EALT3    ADHM3       TIET3     AFLT3      BRGE3      CRIV3  \
# Date
# Mar-86       NaN      NaN         NaN       NaN        NaN        NaN
# Jun-86       NaN      NaN         NaN       NaN        NaN        NaN
# Sep-86       NaN      NaN         NaN       NaN        NaN        NaN
# Dec-86       NaN      NaN         NaN       NaN        NaN        NaN
# Mar-87       NaN      NaN         NaN       NaN        NaN        NaN
# Jun-87       NaN      NaN         NaN       NaN        NaN        NaN
# Sep-87       NaN      NaN         NaN       NaN        NaN        NaN
# Dec-87       NaN      NaN         NaN       NaN        NaN        NaN
# Mar-88       NaN      NaN         NaN       NaN        NaN        NaN
# Jun-88       NaN      NaN         NaN       NaN        NaN        NaN
# Sep-88       NaN      NaN         NaN       NaN        NaN        NaN
# Dec-88       NaN      NaN         NaN       NaN        NaN        NaN
# Mar-89       NaN      NaN         NaN       NaN        NaN        NaN
# Jun-89       NaN      NaN         NaN       NaN        NaN        NaN
# Sep-89       NaN      NaN         NaN       NaN        NaN        NaN
# Dec-89       NaN      NaN         NaN       NaN        NaN        NaN
# Mar-90       NaN      NaN         NaN       NaN        NaN        NaN
# Jun-90       NaN      NaN         NaN       NaN        NaN        NaN
# Sep-90       NaN      NaN         NaN       NaN        NaN        NaN
# Dec-90       NaN      NaN         NaN       NaN        NaN        NaN
# Mar-91       NaN      NaN         NaN       NaN        NaN        NaN
# Jun-91       NaN      NaN         NaN       NaN        NaN        NaN
# Sep-91       NaN      NaN         NaN       NaN        NaN        NaN
# Dec-91       NaN      NaN         NaN       NaN        NaN        NaN
# Mar-92       NaN      NaN         NaN       NaN        NaN        NaN
# Jun-92       NaN      NaN         NaN       NaN        NaN        NaN
# Sep-92       NaN      NaN         NaN       NaN        NaN        NaN
# Dec-92       NaN      NaN         NaN       NaN        NaN        NaN
# Mar-93       NaN      NaN         NaN       NaN        NaN        NaN
# Jun-93       NaN      NaN         NaN       NaN        NaN        NaN
# ...          ...      ...         ...       ...        ...        ...
# Jun-12       NaN  47972.0  16610482.0   82276.0  5583924.0  4766309.0
# Sep-12       NaN  43891.0  16650469.0   86752.0  6881877.0  5122017.0
# Dec-12       NaN  41444.0  16440554.0   93210.0  6470110.0  6091012.0
# Mar-13       NaN  37890.0  17810551.0   94912.0  2599059.0  5556070.0
# Jun-13       NaN  35044.0  17094852.0   82129.0  2576237.0  5359708.0
# Sep-13       NaN  23417.0  16929534.0   78194.0  2583568.0  6125481.0
# Dec-13       NaN  15883.0  16573460.0   83403.0  2529211.0  5899831.0
# Mar-14       NaN   7536.0  17641297.0   86955.0  2598710.0  5897130.0
# Jun-14       NaN   5272.0  16535240.0   86689.0  2677653.0  5281664.0
# Sep-14       NaN   5133.0  17279281.0   90631.0  2863920.0  5388309.0
# Dec-14       NaN   1845.0  17673814.0   83910.0  2861695.0  5142272.0
# Mar-15       NaN   6657.0  18827437.0   88006.0  2810046.0  5312531.0
# Jun-15       NaN   6699.0  18520622.0   84363.0  2928911.0  5445174.0
# Sep-15       NaN   7298.0  19504057.0   86611.0  3039904.0  5033858.0
# Dec-15       NaN   6681.0   4636779.0   89374.0  3034511.0  4940418.0
# Mar-16       NaN   6504.0   4451160.0   91902.0  3121051.0  4905294.0
# Jun-16       NaN  20107.0   4033360.0   83769.0  3139367.0  4220715.0
# Sep-16       NaN   2366.0   4120948.0   83438.0  3253621.0  4521745.0
# Dec-16       NaN   2750.0   4099579.0   87616.0  3247532.0  4622923.0
# Mar-17       NaN   2341.0   4254676.0   92996.0  3277794.0  4251383.0
# Jun-17       NaN   1994.0   5149891.0   57797.0  3223743.0  4343998.0
# Sep-17       NaN   2231.0   6636869.0   52500.0  3215031.0  5012006.0
# Dec-17       NaN   2409.0   6817913.0   54791.0  3141175.0  5374288.0
# Mar-18       NaN   2490.0   7329747.0   58525.0  3141965.0  5432538.0
# Jun-18  284943.0    877.0   7705342.0   56757.0  3160338.0  5744706.0
# Sep-18  301426.0   1009.0   7767284.0   62459.0  3157960.0  5668777.0
# Dec-18  347111.0    421.0   7602605.0  206200.0  3162081.0  5936980.0
# Mar-19  345189.0    410.0   7809475.0  212926.0  3152609.0  6203773.0
# Jun-19  345060.0      NaN   7914945.0  218327.0  3211706.0  6396934.0
# Sep-19       NaN      NaN         NaN  227660.0        NaN        NaN
#
# ticker          RPAD3         BRIV3      ALSO3     APTI3     ...      VIVO4  \
# Date                                                         ...
# Mar-86            NaN           NaN        NaN       NaN     ...        NaN
# Jun-86            NaN           NaN        NaN       NaN     ...        NaN
# Sep-86            NaN           NaN        NaN       NaN     ...        NaN
# Dec-86       0.000610           NaN        NaN       NaN     ...        NaN
# Mar-87            NaN           NaN        NaN       NaN     ...        NaN
# Jun-87            NaN           NaN        NaN       NaN     ...        NaN
# Sep-87            NaN           NaN        NaN       NaN     ...        NaN
# Dec-87       0.026936  3.876349e-01        NaN       NaN     ...        NaN
# Mar-88            NaN           NaN        NaN       NaN     ...        NaN
# Jun-88            NaN           NaN        NaN       NaN     ...        NaN
# Sep-88            NaN           NaN        NaN       NaN     ...        NaN
# Dec-88       0.029776  5.562830e-01        NaN       NaN     ...        NaN
# Mar-89       0.047428           NaN        NaN       NaN     ...        NaN
# Jun-89       0.073967           NaN        NaN       NaN     ...        NaN
# Sep-89       0.175619           NaN        NaN       NaN     ...        NaN
# Dec-89       0.544056  6.718400e+00        NaN       NaN     ...        NaN
# Mar-90       2.171377           NaN        NaN       NaN     ...        NaN
# Jun-90       2.693010           NaN        NaN       NaN     ...        NaN
# Sep-90       3.908844           NaN        NaN       NaN     ...        NaN
# Dec-90       6.152188  1.234383e+02        NaN       NaN     ...        NaN
# Mar-91       8.608845           NaN        NaN       NaN     ...        NaN
# Jun-91      12.788147           NaN        NaN       NaN     ...        NaN
# Sep-91      19.883890           NaN        NaN       NaN     ...        NaN
# Dec-91      52.953201  6.154924e+02        NaN       NaN     ...        NaN
# Mar-92     104.520974           NaN        NaN       NaN     ...        NaN
# Jun-92     193.412563           NaN        NaN       NaN     ...        NaN
# Sep-92     361.085128           NaN        NaN       NaN     ...        NaN
# Dec-92     705.246042  8.599402e+03        NaN       NaN     ...        NaN
# Mar-93    1491.841430           NaN        NaN       NaN     ...        NaN
# Jun-93    3339.416695           NaN        NaN       NaN     ...        NaN
# ...               ...           ...        ...       ...     ...        ...
# Jun-12  678199.000000  1.183449e+07  3906029.0  412852.0     ...        NaN
# Sep-12  687125.000000  1.215044e+07  3976418.0  410819.0     ...        NaN
# Dec-12  709015.000000  1.398269e+07  4069681.0  405921.0     ...        NaN
# Mar-13  713285.000000  1.351713e+07  4074778.0  408907.0     ...        NaN
# Jun-13  724070.000000  1.313262e+07  4343586.0  408203.0     ...        NaN
# Sep-13  731259.000000  1.344284e+07  4376833.0  407837.0     ...        NaN
# Dec-13  746955.000000  1.352680e+07  4530037.0  422083.0     ...        NaN
# Mar-14  751635.000000  1.337958e+07  4521557.0  424802.0     ...        NaN
# Jun-14  758632.000000  1.244215e+07  4587526.0  431970.0     ...        NaN
# Sep-14  773496.000000  1.390943e+07  4595862.0  434486.0     ...        NaN
# Dec-14  783632.000000  1.381818e+07  4742333.0  434671.0     ...        NaN
# Mar-15  804063.000000  1.361308e+07  4735628.0  437706.0     ...        NaN
# Jun-15  811016.000000  1.313028e+07  4826448.0  439453.0     ...        NaN
# Sep-15  840336.000000  1.244704e+07  4849733.0  422725.0     ...        NaN
# Dec-15  857499.000000  1.231101e+07  4900842.0  423372.0     ...        NaN
# Mar-16  861845.000000  1.296938e+07  4831519.0  422171.0     ...        NaN
# Jun-16  864229.000000  1.176736e+07  4839446.0  415018.0     ...        NaN
# Sep-16  881173.000000  1.246195e+07  4847524.0  411279.0     ...        NaN
# Dec-16  889310.000000  1.229734e+07  4988081.0  425034.0     ...        NaN
# Mar-17  900230.000000  1.121422e+07  4929500.0  422704.0     ...        NaN
# Jun-17  912131.000000  1.138120e+07  4995494.0  421356.0     ...        NaN
# Sep-17  922072.000000  1.176722e+07  5257481.0  427812.0     ...        NaN
# Dec-17  925349.000000  1.262321e+07  5325661.0  421997.0     ...        NaN
# Mar-18  932713.000000  1.262696e+07  5170763.0  422385.0     ...        NaN
# Jun-18  946549.000000  1.282773e+07  5252838.0  430028.0     ...        NaN
# Sep-18  957208.000000  1.293127e+07  5267446.0  428524.0     ...        NaN
# Dec-18  967257.000000  1.332035e+07  5505253.0  417753.0     ...        NaN
# Mar-19  973382.000000  1.387389e+07  5560514.0  421860.0     ...        NaN
# Jun-19  978807.000000  1.413722e+07  5568642.0  422811.0     ...        NaN
# Sep-19            NaN           NaN        NaN       NaN     ...        NaN
#
# ticker        VTEC4      VULC4         WEGE4         WMBY4  WET4  WISA4  \
# Date
# Mar-86          NaN        NaN           NaN           NaN   NaN    NaN
# Jun-86          NaN        NaN           NaN           NaN   NaN    NaN
# Sep-86          NaN        NaN           NaN           NaN   NaN    NaN
# Dec-86     0.000304        NaN  5.064945e-04           NaN   NaN    NaN
# Mar-87          NaN        NaN           NaN           NaN   NaN    NaN
# Jun-87          NaN        NaN  1.291309e-03           NaN   NaN    NaN
# Sep-87          NaN        NaN           NaN           NaN   NaN    NaN
# Dec-87     0.001061        NaN  3.933632e-03  5.675043e-03   NaN    NaN
# Mar-88          NaN        NaN           NaN           NaN   NaN    NaN
# Jun-88          NaN        NaN  1.102242e-02           NaN   NaN    NaN
# Sep-88          NaN        NaN  2.015437e-02           NaN   NaN    NaN
# Dec-88     0.012085        NaN  3.847897e-02  5.537297e-02   NaN    NaN
# Mar-89     0.021226        NaN  5.751455e-02           NaN   NaN    NaN
# Jun-89     0.021004        NaN  9.050764e-02           NaN   NaN    NaN
# Sep-89     0.064156        NaN  2.207175e-01           NaN   NaN    NaN
# Dec-89     0.195904        NaN  6.389058e-01  9.393491e-01   NaN    NaN
# Mar-90     0.731972        NaN  2.423451e+00           NaN   NaN    NaN
# Jun-90     0.869084        NaN  3.245295e+00           NaN   NaN    NaN
# Sep-90     1.105127        NaN  5.052438e+00           NaN   NaN    NaN
# Dec-90     1.963300        NaN  7.350839e+00  1.068788e+01   NaN    NaN
# Mar-91     2.940105        NaN  9.138853e+00           NaN   NaN    NaN
# Jun-91     3.610528        NaN  1.451966e+01           NaN   NaN    NaN
# Sep-91     5.598851        NaN  2.150474e+01           NaN   NaN    NaN
# Dec-91    18.199342        NaN  5.522262e+01  1.111002e+02   NaN    NaN
# Mar-92    34.367570        NaN  1.030606e+02           NaN   NaN    NaN
# Jun-92    60.867842        NaN  1.844668e+02           NaN   NaN    NaN
# Sep-92   113.848067        NaN  3.521265e+02           NaN   NaN    NaN
# Dec-92   246.296788        NaN  6.858575e+02  1.443474e+03   NaN    NaN
# Mar-93   498.994011        NaN  1.488662e+03           NaN   NaN    NaN
# Jun-93  1063.475757        NaN  3.234225e+03           NaN   NaN    NaN
# ...             ...        ...           ...           ...   ...    ...
# Jun-12          NaN  1539740.0  9.109705e+06  3.370707e+06   NaN    NaN
# Sep-12          NaN  1483676.0  8.757033e+06  3.346407e+06   NaN    NaN
# Dec-12          NaN  1375440.0  8.873550e+06  3.256259e+06   NaN    NaN
# Mar-13          NaN  1328229.0  9.496435e+06  3.212890e+06   NaN    NaN
# Jun-13          NaN  1312813.0  9.542922e+06  3.209295e+06   NaN    NaN
# Sep-13          NaN  1341526.0  9.552065e+06  3.244971e+06   NaN    NaN
# Dec-13          NaN  1267560.0  1.014129e+07  3.262986e+06   NaN    NaN
# Mar-14          NaN  1205119.0  9.898693e+06  3.258251e+06   NaN    NaN
# Jun-14          NaN  1180442.0  1.036267e+07  3.210103e+06   NaN    NaN
# Sep-14          NaN  1242582.0  1.090281e+07  3.407345e+06   NaN    NaN
# Dec-14          NaN  1271514.0  1.178263e+07  3.360092e+06   NaN    NaN
# Mar-15          NaN  1284687.0  1.295130e+07  3.405526e+06   NaN    NaN
# Jun-15          NaN  1278872.0  1.312129e+07  3.393657e+06   NaN    NaN
# Sep-15          NaN  1395985.0  1.428992e+07  3.563138e+06   NaN    NaN
# Dec-15          NaN  1237154.0  1.426154e+07  3.444984e+06   NaN    NaN
# Mar-16          NaN  1117914.0  1.345885e+07  3.473329e+06   NaN    NaN
# Jun-16          NaN  1132195.0  1.304868e+07  3.351412e+06   NaN    NaN
# Sep-16          NaN  1155891.0  1.363482e+07  3.356436e+06   NaN    NaN
# Dec-16          NaN  1078668.0  1.350933e+07           NaN   NaN    NaN
# Mar-17          NaN  1047278.0  1.344603e+07           NaN   NaN    NaN
# Jun-17          NaN  1101293.0  1.418142e+07           NaN   NaN    NaN
# Sep-17          NaN  1081084.0  1.396445e+07           NaN   NaN    NaN
# Dec-17          NaN  1120485.0  1.398599e+07           NaN   NaN    NaN
# Mar-18          NaN  1177315.0  1.452605e+07           NaN   NaN    NaN
# Jun-18          NaN  1113366.0  1.546405e+07           NaN   NaN    NaN
# Sep-18          NaN  1177163.0  1.627413e+07           NaN   NaN    NaN
# Dec-18          NaN  1326773.0  1.539985e+07           NaN   NaN    NaN
# Mar-19          NaN  1342172.0  1.522698e+07           NaN   NaN    NaN
# Jun-19          NaN  1340937.0  1.490781e+07           NaN   NaN    NaN
# Sep-19          NaN        NaN  1.547942e+07           NaN   NaN    NaN
#
# ticker  ILMD4      ESTC4       ZIVI4
# Date
# Mar-86    NaN        NaN         NaN
# Jun-86    NaN        NaN         NaN
# Sep-86    NaN        NaN         NaN
# Dec-86    NaN        NaN    0.000728
# Mar-87    NaN        NaN         NaN
# Jun-87    NaN        NaN         NaN
# Sep-87    NaN        NaN         NaN
# Dec-87    NaN        NaN    0.003529
# Mar-88    NaN        NaN         NaN
# Jun-88    NaN        NaN         NaN
# Sep-88    NaN        NaN         NaN
# Dec-88    NaN        NaN    0.031218
# Mar-89    NaN        NaN         NaN
# Jun-89    NaN        NaN         NaN
# Sep-89    NaN        NaN         NaN
# Dec-89    NaN        NaN    0.559391
# Mar-90    NaN        NaN         NaN
# Jun-90    NaN        NaN         NaN
# Sep-90    NaN        NaN         NaN
# Dec-90    NaN        NaN    6.767294
# Mar-91    NaN        NaN         NaN
# Jun-91    NaN        NaN         NaN
# Sep-91    NaN        NaN         NaN
# Dec-91    NaN        NaN   58.484292
# Mar-92    NaN        NaN         NaN
# Jun-92    NaN        NaN         NaN
# Sep-92    NaN        NaN         NaN
# Dec-92    NaN        NaN  745.686556
# Mar-93    NaN        NaN         NaN
# Jun-93    NaN        NaN         NaN
# ...       ...        ...         ...
# Jun-12    NaN  1151001.0         NaN
# Sep-12    NaN  1239203.0         NaN
# Dec-12    NaN  1239810.0         NaN
# Mar-13    NaN  1921630.0         NaN
# Jun-13    NaN  1969940.0         NaN
# Sep-13    NaN  2096352.0         NaN
# Dec-13    NaN  2138651.0         NaN
# Mar-14    NaN  2324618.0         NaN
# Jun-14    NaN  2364019.0         NaN
# Sep-14    NaN  3172609.0         NaN
# Dec-14    NaN  3514186.0         NaN
# Mar-15    NaN  3818067.0         NaN
# Jun-15    NaN  3866505.0         NaN
# Sep-15    NaN  4322267.0         NaN
# Dec-15    NaN  4360083.0         NaN
# Mar-16    NaN  4274136.0         NaN
# Jun-16    NaN  4172320.0         NaN
# Sep-16    NaN  4279627.0         NaN
# Dec-16    NaN  4141152.0         NaN
# Mar-17    NaN  4314202.0         NaN
# Jun-17    NaN  4425002.0         NaN
# Sep-17    NaN  4394084.0         NaN
# Dec-17    NaN  4021095.0         NaN
# Mar-18    NaN  4290572.0         NaN
# Jun-18    NaN  4237731.0         NaN
# Sep-18    NaN  4201663.0         NaN
# Dec-18    NaN  4102463.0         NaN
# Mar-19    NaN  5652746.0         NaN
# Jun-19    NaN  5564189.0         NaN
# Sep-19    NaN        NaN         NaN
#
# [135 rows x 998 columns]

# %%
# METODOLOGIA
# 1 - Só deixar ON e PN 4
# 2 - Remover tickers com pouco historico

# %%
# estou com o problema de contar o numero máximo de consecutive non NA
# https://stackoverflow.com/questions/41968892/counting-consecutive-numbers-in-a-list
# https://stackoverflow.com/questions/44337512/delete-non-consecutive-values-from-a-dataframe-column
# https://stackoverflow.com/questions/52671308/counting-the-number-of-consecutive-values-that-meets-a-condition-pandas-datafra
# http://blog.adeel.io/2016/10/30/removing-neighboring-consecutive-only-duplicates-in-a-pandas-dataframe/

# %%
# pequeno exemplo de como usar series com booleans
obj = pd.Series([4, 7, -5, -3], index=['a', 'c', 'f', 'k'])
# o obj.index é do tipo pandas.core.indexes.base.Index
# o obj.values é do tipo numpy.ndarray
# obj[1] dá 7, assim como obj['c'] dá 7
type(obj>0)
# a maneira mais fácil de referenciar uma series usando booleans é com uma series de booleans
# Out:
# pandas.core.series.Series

# %%
tickers[tickers.str.contains('.B$')]
# Out:
# 0        QVQP3B
# 9        ALEF3B
# 27       FRRN3B
# 28       FRRN5B
# 29       FRRN6B
# 68       BETP3B
# 95       CABI3B
# 96       CACO3B
# 100      CPTP3B
# 128      ENMA3B
# 129      ENMA5B
# 130      ENMA6B
# 153      CRTE3B
# 154      CRTE5B
# 199      ETRO3B
# 236      OPGM3B
# 279      IVPR3B
# 280      IVPR4B
# 309      LTEL3B
# 310      LTEL5B
# 311     LTEL11B
# 320      SPRT3B
# 336      MNZC3B
# 357      MRSA3B
# 358      MRSA5B
# 359      MRSA6B
# 377      OPHE3B
# 408      PRPT3B
# 448      SLCT3B
# 473      OPSE3B
#          ...
# 602      VDNP3B
# 631      PBEL3B
# 632      PBEL5B
# 633      PBEL6B
# 655      BNPA3B
# 689      CAIA3B
# 742      COBE3B
# 743      COBE5B
# 744      COBE6B
# 767      OPDL3B
# 775      DNEN3B
# 782      CALA3B
# 783      CALA4B
# 855      FTRT3B
# 870      GTDP3B
# 871      GTDP4B
# 950      MAOR3B
# 951      MAOR4B
# 986      NEWT3B
# 1047     PRMN3B
# 1084     OPRE3B
# 1220     TLVT3B
# 1225     TPEC3B
# 1226     TPEC6B
# 1227     TPEC7B
# 1228     TPEC8B
# 1255     VLTR3B
# 1256     VLTR5B
# 1257     VLTR6B
# 1292     OPZI3B
# Name: 0, Length: 74, dtype: object

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])
df2 = pd.DataFrame({'E': ['A4', 'A5', 'A6', 'A7'],
                    'F': ['B4', 'B5', 'B6', 'B7'],
                    'G': ['C4', 'C5', 'C6', 'C7'],
                    'H': ['D4', 'D5', 'D6', 'D7']},
                    index=[0, 1, 2, 3])
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

result = pd.concat([df1, df2],axis=1)
result
[df1, df2]
# Out:
#   File "<ipython-input-78-4ff4fc3df747>", line 19
#     [df1; df2]
#         ^
# SyntaxError: invalid syntax
