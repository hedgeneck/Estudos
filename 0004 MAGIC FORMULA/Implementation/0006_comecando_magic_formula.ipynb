# %%
# O objetivo aqui vai ser arrumar os dados para backtest

# %%
import pandas as pd
import numpy as np
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html

# %%
# Algumas questões sobre markdown
# https://tex.stackexchange.com/questions/130510/write-text-correctly-in-equations #\mathrm and its friends
# https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html
# https://www.ibm.com/support/knowledgecenter/en/SSGNPV_1.1.3/dsx/markd-jupyter.html

# %% [markdown]
# The magic formula ranks companies based on two factors: return on capital and earnings yield.
#
# #### Return on Capital
# $\textrm{ROC} = \textrm{EBIT}/\textrm{(Net Working Capital + Net Fixed Assets)}$
#
# $\begin{split}
# \textrm{Net Fixed Assets} & = \textrm{Total Assets} \\
#  & - \textrm{Total Current Assets} \\
#  & - \textrm{Total Intangibles & Goodwill}
# \end{split}$
#
# #### Earnings yield
# $\textrm{Earnings Yield} = \textrm{EBIT} / \textrm{Enterprise Value}$
#
# $\begin{split}
# \textrm{Enterprise Value} & = \textrm{Market Value of Equity} \\
#  & + \textrm{Net Interest-Bearing Debt}
# \end{split}$

# %%
def org_columns(df):
    '''
    Organiza os dataframes com fundamentos:
        Renomeia columns
        Seleciona apenas tickers de interesse
    '''
    tickers = df.columns.str.extract('(.*)$')[0]
    df.columns = tickers
    on = tickers[tickers.str.contains('.\D3$')]
    pn = tickers[tickers.str.contains('.\D4$')]
    sto_tick = pd.concat([on, pn], ignore_index=True)
    df = df[sto_tick]
    df = df[df.index.str.contains("Mar|Jun|Sep|Dec")]
    df.columns.name = "ticker"
    return df

# %%
# EBIT
ebit_ati = pd.read_excel('../../data/economatica_1/ebit_mensal__ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ebit_can = pd.read_excel('../../data/economatica_1/ebit_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ebit_can.drop(["Jan-86", "Feb-86"], inplace=True)

ebit = pd.concat([ebit_ati,ebit_can],axis=1,sort=False)
ebit = org_columns(ebit)

# %%
# Net Working Capital
nwc_ati = pd.read_excel('../../data/economatica_1/working_capital_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
nwc_can = pd.read_excel('../../data/economatica_1/working_capital_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
nwc_can.drop(["Jan-86", "Feb-86"], inplace=True)

nwc = pd.concat([ebit_ati,ebit_can],axis=1,sort=False)
nwc = org_columns(nwc)

# %%
# Total Assets
ta_ati = pd.read_excel('../../data/economatica_1/total_assets_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ta_can = pd.read_excel('../../data/economatica_1/total_assets_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ta_can.drop(["Jan-86", "Feb-86"], inplace=True)

ta = pd.concat([ta_ati,ta_can],axis=1,sort=False)
ta = org_columns(ta)

# %%
# Ativo Circulante
ac_ati = pd.read_excel('../../data/economatica_1/ativo_circulante_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ac_can = pd.read_excel('../../data/economatica_1/ativo_circulante_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ac_can.drop(["Jan-86", "Feb-86"], inplace=True)

ac = pd.concat([ac_ati,ac_can],axis=1,sort=False)
ac = org_columns(ac)

# %%
# Passivo Circulante
pc_ati = pd.read_excel('../../data/economatica_1/passivo_circulante_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
pc_can = pd.read_excel('../../data/economatica_1/passivo_circulante_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
pc_can.drop(["Jan-86", "Feb-86"], inplace=True)

pc = pd.concat([pc_ati,pc_can],axis=1,sort=False)
pc = org_columns(pc)

# %%
# Total Current Assets
tca = ac - pc

# %%
# Goodwill
gw_ati = pd.read_excel('../../data/economatica_1/goodwill_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
gw_can = pd.read_excel('../../data/economatica_1/goodwill_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
# pc_can.drop(["Jan-86", "Feb-86"], inplace=True)

gw = pd.concat([gw_ati,gw_can],axis=1,sort=False)
gw = org_columns(gw)

# %%
# Net Fixed Assets
nfa = ta - tca - gw

# %%
# Return on Capital (ROC)
roc = ebit / (nwc + nfa)

# %%
# Market Value of Equity
mve_ati = pd.read_excel('../../data/economatica_1/valor_mercado_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
mve_can = pd.read_excel('../../data/economatica_1/valor_mercado_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
mve_can.drop(["Jan-86", "Feb-86"], inplace=True)

mve = pd.concat([mve_ati,mve_can],axis=1,sort=False)
mve = org_columns(mve)

# %%
# Net Interest-Bearing Debt
nibd_ati = pd.read_excel('../../data/economatica_1/net_debt_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
nibd_can = pd.read_excel('../../data/economatica_1/net_debt_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
nibd_can.drop(["Jan-86", "Feb-86"], inplace=True)

nibd = pd.concat([nibd_ati,nibd_can],axis=1,sort=False)
nibd = org_columns(nibd)

# %%
# Enterprise Level
ev = mve + nibd

# %%
# Earnings Yield
ey = ebit/ev

# %%
# Fazer com que todas linhas cuspam output
# https://stackoverflow.com/questions/31764006/ipython-notebook-display-every-line-output-without-print
# ebit.shape # número de linhas e colunas
# ebit.isna().sum().sum() número de NAs em um dataframe

# %%
ebit.shape
ebit.isna().sum().sum()
# Out:
# 89129

# %%
nwc.shape
nwc.isna().sum().sum()
# Out:
# 89129

# %%
ta.shape
ta.isna().sum().sum()
# Out:
# 84743

# %%
ac.shape
ac.isna().sum().sum()
# Out:
# 84884

# %%
pc.shape
pc.isna().sum().sum()
# Out:
# 84883

# %%
gw.shape
gw.isna().sum().sum()
# Out:
# 105986

# %%
roc.shape
roc.isna().sum().sum()
# Out:
# 106108

# %%
mve.shape
mve.isna().sum().sum()
# Out:
# 78722

# %%
nibd.shape
nibd.isna().sum().sum()
# Out:
# 89304

# %%
ev.shape
ev.isna().sum().sum()
# Out:
# (135, 999)

# %%
x = ebit+nwc+ta+gw
x.isna().sum().sum()
# Out:
# 106107

# %%
nrow, ncol = gw.shape
nrow*ncol
# Out:
# 134865

# %%
ey
# Out:
# ticker     AALR3  ABCB3  ABCB4     ABEV3  ABYA3     ACES3     ACES4  ACGU3  \
# Date
# Mar-86       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-86       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Sep-86       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Dec-86       NaN    NaN    NaN  0.346678    NaN       NaN       NaN    NaN
# Mar-87       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-87       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Sep-87       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Dec-87       NaN    NaN    NaN -0.224333    NaN       NaN       NaN    NaN
# Mar-88       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-88       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Sep-88       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Dec-88       NaN    NaN    NaN -0.052208    NaN       NaN       NaN    NaN
# Mar-89       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-89       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Sep-89       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Dec-89       NaN    NaN    NaN  0.022460    NaN       NaN       NaN    NaN
# Mar-90       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-90       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Sep-90       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Dec-90       NaN    NaN    NaN  0.983204    NaN       NaN       NaN    NaN
# Mar-91       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-91       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Sep-91       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Dec-91       NaN    NaN    NaN  0.101297    NaN       NaN       NaN    NaN
# Mar-92       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-92       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Sep-92       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Dec-92       NaN    NaN    NaN  0.141612    NaN -0.000295 -0.000295    NaN
# Mar-93       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-93       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# ...          ...    ...    ...       ...    ...       ...       ...    ...
# Jun-12       NaN    NaN    NaN  0.025695    NaN       NaN       NaN    NaN
# Sep-12       NaN    NaN    NaN  0.041130    NaN       NaN       NaN    NaN
# Dec-12       NaN    NaN    NaN  0.053714    NaN       NaN       NaN    NaN
# Mar-13       NaN    NaN    NaN  0.012004    NaN       NaN       NaN    NaN
# Jun-13       NaN    NaN    NaN  0.022643    NaN       NaN       NaN    NaN
# Sep-13       NaN    NaN    NaN  0.036086    NaN       NaN       NaN    NaN
# Dec-13       NaN    NaN    NaN  0.058627    NaN       NaN       NaN    NaN
# Mar-14       NaN    NaN    NaN  0.013519    NaN       NaN       NaN    NaN
# Jun-14       NaN    NaN    NaN  0.025876    NaN       NaN       NaN    NaN
# Sep-14       NaN    NaN    NaN  0.039432    NaN       NaN       NaN    NaN
# Dec-14       NaN    NaN    NaN  0.064135    NaN       NaN       NaN    NaN
# Mar-15       NaN    NaN    NaN  0.015446    NaN       NaN       NaN    NaN
# Jun-15       NaN    NaN    NaN  0.025505    NaN       NaN       NaN    NaN
# Sep-15       NaN    NaN    NaN  0.039508    NaN       NaN       NaN    NaN
# Dec-15       NaN    NaN    NaN  0.069628    NaN       NaN       NaN    NaN
# Mar-16       NaN    NaN    NaN  0.015017    NaN       NaN       NaN    NaN
# Jun-16       NaN    NaN    NaN  0.025955    NaN       NaN       NaN    NaN
# Sep-16       NaN    NaN    NaN  0.035177    NaN       NaN       NaN    NaN
# Dec-16  0.050637    NaN    NaN  0.067130    NaN       NaN       NaN    NaN
# Mar-17  0.011204    NaN    NaN  0.012314    NaN       NaN       NaN    NaN
# Jun-17  0.022574    NaN    NaN  0.023066    NaN       NaN       NaN    NaN
# Sep-17  0.038033    NaN    NaN  0.031199    NaN       NaN       NaN    NaN
# Dec-17  0.031166    NaN    NaN  0.050302    NaN       NaN       NaN    NaN
# Mar-18  0.012992    NaN    NaN  0.010036    NaN       NaN       NaN    NaN
# Jun-18  0.029108    NaN    NaN  0.026781    NaN       NaN       NaN    NaN
# Sep-18  0.049519    NaN    NaN  0.038357    NaN       NaN       NaN    NaN
# Dec-18  0.065258    NaN    NaN  0.073003    NaN       NaN       NaN    NaN
# Mar-19  0.015969    NaN    NaN  0.015777    NaN       NaN       NaN    NaN
# Jun-19  0.032009    NaN    NaN  0.027944    NaN       NaN       NaN    NaN
# Sep-19       NaN    NaN    NaN  0.036775    NaN       NaN       NaN    NaN
#
# ticker     ADHM3     AEDU3    ...     WISA3  WISA4     WIZS3     WLMM3  \
# Date                          ...
# Mar-86       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-86       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Sep-86       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Dec-86       NaN       NaN    ...       NaN    NaN       NaN  0.253990
# Mar-87       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-87       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Sep-87       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Dec-87       NaN       NaN    ...       NaN    NaN       NaN  1.279382
# Mar-88       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-88       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Sep-88       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Dec-88       NaN       NaN    ...       NaN    NaN       NaN  0.228753
# Mar-89       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-89       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Sep-89       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Dec-89       NaN       NaN    ...       NaN    NaN       NaN -0.269466
# Mar-90       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-90       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Sep-90       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Dec-90       NaN       NaN    ...       NaN    NaN       NaN  0.945752
# Mar-91       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-91       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Sep-91       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Dec-91       NaN       NaN    ...       NaN    NaN       NaN -0.150959
# Mar-92       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-92       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Sep-92       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Dec-92       NaN       NaN    ...       NaN    NaN       NaN -0.076703
# Mar-93       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-93       NaN       NaN    ...       NaN    NaN       NaN       NaN
# ...          ...       ...    ...       ...    ...       ...       ...
# Jun-12 -0.026499  0.000595    ...       NaN    NaN       NaN       NaN
# Sep-12 -0.036566  0.000542    ...       NaN    NaN       NaN  0.014289
# Dec-12 -0.065483  0.000587    ...       NaN    NaN       NaN  0.165053
# Mar-13 -0.031132  0.000302    ...       NaN    NaN       NaN  0.010743
# Jun-13 -0.151465  0.000459    ...       NaN    NaN       NaN  0.046561
# Sep-13 -0.203516  0.000430    ...       NaN    NaN       NaN  0.086763
# Dec-13 -0.287314  0.000364    ...       NaN    NaN       NaN  0.101013
# Mar-14 -0.016132  0.000204    ...       NaN    NaN       NaN  0.019029
# Jun-14 -0.066805  0.000320    ...       NaN    NaN       NaN  0.022636
# Sep-14 -0.119702       NaN    ...       NaN    NaN       NaN  0.046874
# Dec-14 -0.390682       NaN    ...       NaN    NaN       NaN  0.028152
# Mar-15 -0.025124       NaN    ...       NaN    NaN       NaN -0.015003
# Jun-15 -0.053307       NaN    ...       NaN    NaN  0.030113 -0.010392
# Sep-15 -0.154867       NaN    ...       NaN    NaN  0.080400 -0.009066
# Dec-15 -0.338411       NaN    ...       NaN    NaN  0.106083 -0.040067
# Mar-16 -0.057794       NaN    ...       NaN    NaN  0.026260 -0.060867
# Jun-16 -0.058660       NaN    ...       NaN    NaN  0.051290 -0.133278
# Sep-16 -0.120921       NaN    ...       NaN    NaN  0.069672 -0.182624
# Dec-16 -0.315373       NaN    ...       NaN    NaN  0.100183 -0.320575
# Mar-17 -0.086546       NaN    ...       NaN    NaN  0.024585 -0.009131
# Jun-17 -0.160363       NaN    ...       NaN    NaN  0.042306 -0.012743
# Sep-17 -0.207926       NaN    ...       NaN    NaN  0.073616 -0.001293
# Dec-17 -0.313476       NaN    ...       NaN    NaN  0.133864 -0.042936
# Mar-18 -0.159742       NaN    ...       NaN    NaN  0.030443  0.018905
# Jun-18 -0.056627       NaN    ...       NaN    NaN  0.097645  0.021164
# Sep-18 -0.137756       NaN    ...       NaN    NaN  0.168276  0.085845
# Dec-18 -0.239676       NaN    ...       NaN    NaN  0.281467  0.122102
# Mar-19 -0.142883       NaN    ...       NaN    NaN  0.069235  0.044955
# Jun-19       NaN       NaN    ...       NaN    NaN  0.099199  0.120518
# Sep-19       NaN       NaN    ...       NaN    NaN       NaN       NaN
#
# ticker     WLMM4     WMBY3     WMBY4  WWOW3     YDUQ3     ZIVI4
# Date
# Mar-86       NaN       NaN       NaN    NaN       NaN       NaN
# Jun-86       NaN       NaN       NaN    NaN       NaN       NaN
# Sep-86       NaN       NaN       NaN    NaN       NaN       NaN
# Dec-86  0.253990       NaN       NaN    NaN       NaN       NaN
# Mar-87       NaN       NaN       NaN    NaN       NaN       NaN
# Jun-87       NaN       NaN       NaN    NaN       NaN       NaN
# Sep-87       NaN       NaN       NaN    NaN       NaN       NaN
# Dec-87  1.279382 -0.003377 -0.003377    NaN       NaN       NaN
# Mar-88       NaN       NaN       NaN    NaN       NaN       NaN
# Jun-88       NaN       NaN       NaN    NaN       NaN       NaN
# Sep-88       NaN       NaN       NaN    NaN       NaN       NaN
# Dec-88  0.228753 -0.003979 -0.003979    NaN       NaN       NaN
# Mar-89       NaN       NaN       NaN    NaN       NaN       NaN
# Jun-89       NaN       NaN       NaN    NaN       NaN       NaN
# Sep-89       NaN       NaN       NaN    NaN       NaN       NaN
# Dec-89 -0.269466  0.003679  0.003679    NaN       NaN  0.000967
# Mar-90       NaN       NaN       NaN    NaN       NaN       NaN
# Jun-90       NaN       NaN       NaN    NaN       NaN       NaN
# Sep-90       NaN       NaN       NaN    NaN       NaN       NaN
# Dec-90  0.945752  0.002509  0.002509    NaN       NaN  0.000978
# Mar-91       NaN       NaN       NaN    NaN       NaN       NaN
# Jun-91       NaN       NaN       NaN    NaN       NaN       NaN
# Sep-91       NaN       NaN       NaN    NaN       NaN       NaN
# Dec-91 -0.150959 -0.000476 -0.000476    NaN       NaN  0.000665
# Mar-92       NaN       NaN       NaN    NaN       NaN       NaN
# Jun-92       NaN       NaN       NaN    NaN       NaN       NaN
# Sep-92       NaN       NaN       NaN    NaN       NaN       NaN
# Dec-92 -0.076703 -0.001475 -0.001475    NaN       NaN -0.000268
# Mar-93       NaN       NaN       NaN    NaN       NaN       NaN
# Jun-93       NaN       NaN       NaN    NaN       NaN       NaN
# ...          ...       ...       ...    ...       ...       ...
# Jun-12       NaN       NaN       NaN    NaN  0.032106       NaN
# Sep-12  0.014289       NaN       NaN    NaN  0.041262       NaN
# Dec-12  0.165053       NaN       NaN    NaN  0.041705       NaN
# Mar-13  0.010743       NaN       NaN    NaN  0.018298       NaN
# Jun-13  0.046561       NaN       NaN    NaN  0.027993       NaN
# Sep-13  0.086763       NaN       NaN    NaN  0.044581       NaN
# Dec-13  0.101013       NaN       NaN    NaN  0.044991       NaN
# Mar-14  0.019029       NaN       NaN    NaN  0.017646       NaN
# Jun-14  0.022636       NaN       NaN    NaN  0.023914       NaN
# Sep-14  0.046874       NaN       NaN    NaN  0.042283       NaN
# Dec-14  0.028152       NaN       NaN    NaN  0.057920       NaN
# Mar-15 -0.015003       NaN       NaN    NaN  0.027116       NaN
# Jun-15 -0.010392       NaN       NaN    NaN  0.048735       NaN
# Sep-15 -0.009066       NaN       NaN    NaN  0.095646       NaN
# Dec-15 -0.040067       NaN       NaN    NaN  0.110956       NaN
# Mar-16 -0.060867       NaN       NaN    NaN  0.036502       NaN
# Jun-16 -0.133278       NaN       NaN    NaN  0.026186       NaN
# Sep-16 -0.182624       NaN       NaN    NaN  0.051784       NaN
# Dec-16 -0.320575       NaN       NaN    NaN  0.083605       NaN
# Mar-17 -0.009131       NaN       NaN    NaN  0.029565       NaN
# Jun-17 -0.012743       NaN       NaN    NaN  0.072073       NaN
# Sep-17 -0.001293       NaN       NaN    NaN  0.055864       NaN
# Dec-17 -0.042936       NaN       NaN    NaN  0.053293       NaN
# Mar-18  0.018905       NaN       NaN    NaN  0.026153       NaN
# Jun-18  0.021164       NaN       NaN    NaN  0.067528       NaN
# Sep-18  0.085845       NaN       NaN    NaN  0.102675       NaN
# Dec-18  0.122102       NaN       NaN    NaN  0.108278       NaN
# Mar-19  0.044955       NaN       NaN    NaN  0.031843       NaN
# Jun-19  0.120518       NaN       NaN    NaN  0.054566       NaN
# Sep-19       NaN       NaN       NaN    NaN       NaN       NaN
#
# [135 rows x 999 columns]

# %%
tickers = tot_ass.columns.str.extract('(.*)$')[0]
tot_ass.columns = tickers
# https://www.debuggex.com/cheatsheet/regex/python
# https://www.dataquest.io/blog/regex-cheatsheet/
on = tickers[tickers.str.contains('.\D3$')]
pn = tickers[tickers.str.contains('.\D4$')]
sto_tick = pd.concat([on, pn], ignore_index=True)
tot_ass = tot_ass[sto_tick]
tot_ass = tot_ass[tot_ass.index.str.contains("Mar|Jun|Sep|Dec")]
tot_ass.columns.name = "ticker"

# %%
# remover colums e row with NA de um dataframe é bem fácil
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html
stocks = tot_ass.loc["Dec-98":"Sep-19"]
stocks = stocks.dropna(axis="columns")

# %%
tca
# Out:
# ticker    EALT3    ADHM3      TIET3    AFLT3     BRGE3      CRIV3  \
# Date
# Mar-86      NaN      NaN        NaN      NaN       NaN        NaN
# Jun-86      NaN      NaN        NaN      NaN       NaN        NaN
# Sep-86      NaN      NaN        NaN      NaN       NaN        NaN
# Dec-86      NaN      NaN        NaN      NaN       NaN        NaN
# Mar-87      NaN      NaN        NaN      NaN       NaN        NaN
# Jun-87      NaN      NaN        NaN      NaN       NaN        NaN
# Sep-87      NaN      NaN        NaN      NaN       NaN        NaN
# Dec-87      NaN      NaN        NaN      NaN       NaN        NaN
# Mar-88      NaN      NaN        NaN      NaN       NaN        NaN
# Jun-88      NaN      NaN        NaN      NaN       NaN        NaN
# Sep-88      NaN      NaN        NaN      NaN       NaN        NaN
# Dec-88      NaN      NaN        NaN      NaN       NaN        NaN
# Mar-89      NaN      NaN        NaN      NaN       NaN        NaN
# Jun-89      NaN      NaN        NaN      NaN       NaN        NaN
# Sep-89      NaN      NaN        NaN      NaN       NaN        NaN
# Dec-89      NaN      NaN        NaN      NaN       NaN        NaN
# Mar-90      NaN      NaN        NaN      NaN       NaN        NaN
# Jun-90      NaN      NaN        NaN      NaN       NaN        NaN
# Sep-90      NaN      NaN        NaN      NaN       NaN        NaN
# Dec-90      NaN      NaN        NaN      NaN       NaN        NaN
# Mar-91      NaN      NaN        NaN      NaN       NaN        NaN
# Jun-91      NaN      NaN        NaN      NaN       NaN        NaN
# Sep-91      NaN      NaN        NaN      NaN       NaN        NaN
# Dec-91      NaN      NaN        NaN      NaN       NaN        NaN
# Mar-92      NaN      NaN        NaN      NaN       NaN        NaN
# Jun-92      NaN      NaN        NaN      NaN       NaN        NaN
# Sep-92      NaN      NaN        NaN      NaN       NaN        NaN
# Dec-92      NaN      NaN        NaN      NaN       NaN        NaN
# Mar-93      NaN      NaN        NaN      NaN       NaN        NaN
# Jun-93      NaN      NaN        NaN      NaN       NaN        NaN
# ...         ...      ...        ...      ...       ...        ...
# Jun-12      NaN -19275.0   734967.0  58644.0  429141.0   922027.0
# Sep-12      NaN -23622.0   480697.0  68630.0   23257.0  1073151.0
# Dec-12      NaN -27404.0   411268.0  69064.0  338140.0  1331111.0
# Mar-13      NaN -30563.0   629207.0  70506.0  471894.0  1433908.0
# Jun-13      NaN -40009.0  1218279.0  63407.0  249505.0  1160216.0
# Sep-13      NaN -43225.0   981946.0  58877.0  485522.0  1619574.0
# Dec-13      NaN -48684.0   585107.0  56822.0 -188527.0  1241649.0
# Mar-14      NaN -11633.0   917554.0  62056.0  467293.0  1153746.0
# Jun-14      NaN -12602.0   -21293.0  49891.0  250252.0  1173337.0
# Sep-14      NaN -14485.0  -258924.0  56281.0  508811.0   544375.0
# Dec-14      NaN -16987.0  -124906.0  58455.0  519737.0   495934.0
# Mar-15      NaN -24248.0   355603.0  63986.0  521027.0   706394.0
# Jun-15      NaN -26679.0   325980.0  63027.0  521556.0   155927.0
# Sep-15      NaN -33496.0   378359.0  69493.0  564934.0   772182.0
# Dec-15      NaN -34361.0   269448.0  66939.0  565326.0   972243.0
# Mar-16      NaN -32954.0   367321.0  71600.0  587170.0   980642.0
# Jun-16      NaN   1838.0  -167759.0  64507.0  657218.0  1016645.0
# Sep-16      NaN  -1054.0  -136987.0  61381.0  625365.0   290843.0
# Dec-16      NaN  -2321.0   -51466.0  64921.0  572940.0   358489.0
# Mar-17      NaN  -4113.0    20057.0  43079.0  563679.0   358750.0
# Jun-17      NaN  -4719.0   374081.0  48009.0  603738.0   668202.0
# Sep-17      NaN  -5787.0  -424703.0  45932.0  598199.0  1891469.0
# Dec-17      NaN  -7574.0  -417631.0  50627.0  587483.0  2847988.0
# Mar-18      NaN  -7636.0   911893.0  48773.0  584716.0  2372274.0
# Jun-18   9794.0  -8878.0   956834.0  51904.0  616246.0  1950312.0
# Sep-18   7448.0 -13607.0   170535.0  57003.0  618382.0  1323597.0
# Dec-18  -3636.0 -14184.0   154947.0  49695.0  615147.0   958947.0
# Mar-19  25154.0 -15294.0  -328110.0  56360.0  641433.0   884174.0
# Jun-19   8271.0      NaN   211549.0  62728.0  655681.0   892924.0
# Sep-19      NaN      NaN        NaN  71595.0       NaN        NaN
#
# ticker         RPAD3         BRIV3     ALSO3    APTI3    ...      VIVO4  \
# Date                                                     ...
# Mar-86           NaN           NaN       NaN      NaN    ...        NaN
# Jun-86           NaN           NaN       NaN      NaN    ...        NaN
# Sep-86           NaN           NaN       NaN      NaN    ...        NaN
# Dec-86      0.000050           NaN       NaN      NaN    ...        NaN
# Mar-87           NaN           NaN       NaN      NaN    ...        NaN
# Jun-87           NaN           NaN       NaN      NaN    ...        NaN
# Sep-87           NaN           NaN       NaN      NaN    ...        NaN
# Dec-87      0.001263 -1.352632e-01       NaN      NaN    ...        NaN
# Mar-88           NaN           NaN       NaN      NaN    ...        NaN
# Jun-88           NaN           NaN       NaN      NaN    ...        NaN
# Sep-88           NaN           NaN       NaN      NaN    ...        NaN
# Dec-88      0.001063 -1.512922e-01       NaN      NaN    ...        NaN
# Mar-89      0.002217           NaN       NaN      NaN    ...        NaN
# Jun-89      0.000071           NaN       NaN      NaN    ...        NaN
# Sep-89      0.003626           NaN       NaN      NaN    ...        NaN
# Dec-89      0.003024 -2.442303e+00       NaN      NaN    ...        NaN
# Mar-90     -0.022508           NaN       NaN      NaN    ...        NaN
# Jun-90     -0.040484           NaN       NaN      NaN    ...        NaN
# Sep-90      0.008164           NaN       NaN      NaN    ...        NaN
# Dec-90     -0.010136 -1.307593e+01       NaN      NaN    ...        NaN
# Mar-91      0.033909           NaN       NaN      NaN    ...        NaN
# Jun-91     -0.038503           NaN       NaN      NaN    ...        NaN
# Sep-91      0.024672           NaN       NaN      NaN    ...        NaN
# Dec-91     -0.316972 -1.062793e+02       NaN      NaN    ...        NaN
# Mar-92      5.103922           NaN       NaN      NaN    ...        NaN
# Jun-92      9.289709           NaN       NaN      NaN    ...        NaN
# Sep-92     21.071155           NaN       NaN      NaN    ...        NaN
# Dec-92     31.338293 -1.161135e+03       NaN      NaN    ...        NaN
# Mar-93     77.545581           NaN       NaN      NaN    ...        NaN
# Jun-93     77.696423           NaN       NaN      NaN    ...        NaN
# ...              ...           ...       ...      ...    ...        ...
# Jun-12  -2164.000000  1.797884e+06  527886.0  22194.0    ...        NaN
# Sep-12   -375.000000  1.514820e+05  438218.0  24453.0    ...        NaN
# Dec-12   -969.000000  8.297570e+05  460758.0  25627.0    ...        NaN
# Mar-13   -948.000000  1.947740e+05  448188.0  34152.0    ...        NaN
# Jun-13   1232.000000  6.014210e+05  414660.0  35099.0    ...        NaN
# Sep-13   2404.000000  1.170492e+06  354058.0  29823.0    ...        NaN
# Dec-13   -986.000000  1.336015e+06  257114.0  21908.0    ...        NaN
# Mar-14   4089.000000  1.011565e+06  243914.0  21658.0    ...        NaN
# Jun-14   2151.000000  1.281258e+06  262133.0  19938.0    ...        NaN
# Sep-14   2988.000000  5.918930e+05  253003.0  20339.0    ...        NaN
# Dec-14  -1031.000000  1.752681e+06  210217.0  63089.0    ...        NaN
# Mar-15   3863.000000  1.860686e+06  217051.0  64472.0    ...        NaN
# Jun-15   7464.000000  1.498920e+06  158591.0  62281.0    ...        NaN
# Sep-15   7092.000000  1.204466e+06  148024.0  61945.0    ...        NaN
# Dec-15   3566.000000  1.426771e+06   98421.0  70083.0    ...        NaN
# Mar-16   3052.000000  2.140221e+06  110416.0  62980.0    ...        NaN
# Jun-16   1315.000000  2.365644e+06  105957.0  54185.0    ...        NaN
# Sep-16   1358.000000  2.243489e+06  110077.0  49305.0    ...        NaN
# Dec-16    129.000000  2.061783e+06   87256.0  55962.0    ...        NaN
# Mar-17   -294.000000  2.607905e+06  -42958.0  49594.0    ...        NaN
# Jun-17  -1920.000000  2.511724e+06  -41009.0  41145.0    ...        NaN
# Sep-17  -2957.000000  2.180577e+06  218891.0  43793.0    ...        NaN
# Dec-17  15671.000000  2.535476e+06  192802.0  42756.0    ...        NaN
# Mar-18  15427.000000  2.535149e+06   44038.0  37718.0    ...        NaN
# Jun-18  12711.000000  3.302283e+06   40772.0  34392.0    ...        NaN
# Sep-18  12146.000000  3.596850e+06   44881.0  28661.0    ...        NaN
# Dec-18   7161.000000  3.520310e+06   89797.0  27158.0    ...        NaN
# Mar-19   6520.000000  3.271421e+06  334806.0  19312.0    ...        NaN
# Jun-19   5008.000000  2.651405e+06  156354.0  14687.0    ...        NaN
# Sep-19           NaN           NaN       NaN      NaN    ...        NaN
#
# ticker       VTEC4     VULC4         WEGE4          WMBY4  WET4  WISA4  ILMD4  \
# Date
# Mar-86         NaN       NaN           NaN            NaN   NaN    NaN    NaN
# Jun-86         NaN       NaN           NaN            NaN   NaN    NaN    NaN
# Sep-86         NaN       NaN           NaN            NaN   NaN    NaN    NaN
# Dec-86   -0.000048       NaN  7.967200e-05            NaN   NaN    NaN    NaN
# Mar-87         NaN       NaN           NaN            NaN   NaN    NaN    NaN
# Jun-87         NaN       NaN  2.256742e-04            NaN   NaN    NaN    NaN
# Sep-87         NaN       NaN           NaN            NaN   NaN    NaN    NaN
# Dec-87   -0.000593       NaN  4.804855e-04       0.000626   NaN    NaN    NaN
# Mar-88         NaN       NaN           NaN            NaN   NaN    NaN    NaN
# Jun-88         NaN       NaN  1.477176e-03            NaN   NaN    NaN    NaN
# Sep-88         NaN       NaN  3.142768e-03            NaN   NaN    NaN    NaN
# Dec-88   -0.006009       NaN  6.247079e-03       0.006348   NaN    NaN    NaN
# Mar-89   -0.011084       NaN  8.316727e-03            NaN   NaN    NaN    NaN
# Jun-89   -0.014517       NaN  1.345127e-02            NaN   NaN    NaN    NaN
# Sep-89   -0.038243       NaN  3.624836e-02            NaN   NaN    NaN    NaN
# Dec-89   -0.118062       NaN  6.893782e-02       0.059484   NaN    NaN    NaN
# Mar-90   -0.475692       NaN  1.046585e-01            NaN   NaN    NaN    NaN
# Jun-90   -0.734448       NaN  3.596251e-01            NaN   NaN    NaN    NaN
# Sep-90   -1.080773       NaN  6.480858e-01            NaN   NaN    NaN    NaN
# Dec-90   -1.092088       NaN  9.180127e-01       0.616365   NaN    NaN    NaN
# Mar-91   -1.715747       NaN  8.282284e-01            NaN   NaN    NaN    NaN
# Jun-91   -2.217929       NaN  1.436491e+00            NaN   NaN    NaN    NaN
# Sep-91   -3.178255       NaN  2.642389e+00            NaN   NaN    NaN    NaN
# Dec-91   -9.748451       NaN  5.025428e+00       4.352098   NaN    NaN    NaN
# Mar-92  -16.741497       NaN  6.446632e+00            NaN   NaN    NaN    NaN
# Jun-92  -33.845699       NaN  1.314627e+01            NaN   NaN    NaN    NaN
# Sep-92  -65.420748       NaN  3.139714e+01            NaN   NaN    NaN    NaN
# Dec-92 -117.260147       NaN  1.054094e+02     125.836727   NaN    NaN    NaN
# Mar-93 -255.629040       NaN  2.749070e+02            NaN   NaN    NaN    NaN
# Jun-93 -494.796897       NaN  6.727549e+02            NaN   NaN    NaN    NaN
# ...            ...       ...           ...            ...   ...    ...    ...
# Jun-12         NaN   85588.0  2.790040e+06  694505.000000   NaN    NaN    NaN
# Sep-12         NaN  119191.0  2.780941e+06  744876.000000   NaN    NaN    NaN
# Dec-12         NaN  106305.0  2.697193e+06  688498.000000   NaN    NaN    NaN
# Mar-13         NaN   82299.0  3.458581e+06  628750.000000   NaN    NaN    NaN
# Jun-13         NaN  127882.0  3.499006e+06  768952.000000   NaN    NaN    NaN
# Sep-13         NaN  129440.0  3.597267e+06  572888.000000   NaN    NaN    NaN
# Dec-13         NaN   58461.0  4.273739e+06  563659.000000   NaN    NaN    NaN
# Mar-14         NaN   10306.0  4.096165e+06  495231.000000   NaN    NaN    NaN
# Jun-14         NaN   15643.0  4.402301e+06  388947.000000   NaN    NaN    NaN
# Sep-14         NaN   64000.0  4.444557e+06  742690.000000   NaN    NaN    NaN
# Dec-14         NaN  133463.0  4.717372e+06  731021.000000   NaN    NaN    NaN
# Mar-15         NaN  117169.0  4.960836e+06  714933.000000   NaN    NaN    NaN
# Jun-15         NaN  182229.0  5.022307e+06  602546.000000   NaN    NaN    NaN
# Sep-15         NaN    6375.0  5.081662e+06  597060.000000   NaN    NaN    NaN
# Dec-15         NaN  -58323.0  6.094494e+06  651324.000000   NaN    NaN    NaN
# Mar-16         NaN  -84370.0  5.655931e+06  740489.000000   NaN    NaN    NaN
# Jun-16         NaN  -92859.0  5.531309e+06  508611.000000   NaN    NaN    NaN
# Sep-16         NaN  -22312.0  6.160579e+06  501704.000000   NaN    NaN    NaN
# Dec-16         NaN  175549.0  5.848628e+06            NaN   NaN    NaN    NaN
# Mar-17         NaN  175576.0  5.984948e+06            NaN   NaN    NaN    NaN
# Jun-17         NaN  212460.0  5.743448e+06            NaN   NaN    NaN    NaN
# Sep-17         NaN  255286.0  5.472793e+06            NaN   NaN    NaN    NaN
# Dec-17         NaN  401396.0  5.088879e+06            NaN   NaN    NaN    NaN
# Mar-18         NaN  422290.0  5.413364e+06            NaN   NaN    NaN    NaN
# Jun-18         NaN  440491.0  5.015174e+06            NaN   NaN    NaN    NaN
# Sep-18         NaN  470962.0  4.495562e+06            NaN   NaN    NaN    NaN
# Dec-18         NaN  525134.0  4.404577e+06            NaN   NaN    NaN    NaN
# Mar-19         NaN  540980.0  4.230338e+06            NaN   NaN    NaN    NaN
# Jun-19         NaN  563945.0  4.402683e+06            NaN   NaN    NaN    NaN
# Sep-19         NaN       NaN  5.112817e+06            NaN   NaN    NaN    NaN
#
# ticker      ESTC4      ZIVI4
# Date
# Mar-86        NaN        NaN
# Jun-86        NaN        NaN
# Sep-86        NaN        NaN
# Dec-86        NaN   0.000071
# Mar-87        NaN        NaN
# Jun-87        NaN        NaN
# Sep-87        NaN        NaN
# Dec-87        NaN   0.000473
# Mar-88        NaN        NaN
# Jun-88        NaN        NaN
# Sep-88        NaN        NaN
# Dec-88        NaN   0.004325
# Mar-89        NaN        NaN
# Jun-89        NaN        NaN
# Sep-89        NaN        NaN
# Dec-89        NaN   0.057676
# Mar-90        NaN        NaN
# Jun-90        NaN        NaN
# Sep-90        NaN        NaN
# Dec-90        NaN  -0.134809
# Mar-91        NaN        NaN
# Jun-91        NaN        NaN
# Sep-91        NaN        NaN
# Dec-91        NaN  -2.762041
# Mar-92        NaN        NaN
# Jun-92        NaN        NaN
# Sep-92        NaN        NaN
# Dec-92        NaN -44.359294
# Mar-93        NaN        NaN
# Jun-93        NaN        NaN
# ...           ...        ...
# Jun-12   366243.0        NaN
# Sep-12   364519.0        NaN
# Dec-12   317915.0        NaN
# Mar-13   979803.0        NaN
# Jun-13  1000760.0        NaN
# Sep-13  1054988.0        NaN
# Dec-13   979892.0        NaN
# Mar-14  1082332.0        NaN
# Jun-14  1187848.0        NaN
# Sep-14   869623.0        NaN
# Dec-14  1076985.0        NaN
# Mar-15  1091347.0        NaN
# Jun-15  1204651.0        NaN
# Sep-15  1468988.0        NaN
# Dec-15  1371858.0        NaN
# Mar-16  1033724.0        NaN
# Jun-16  1060084.0        NaN
# Sep-16   996049.0        NaN
# Dec-16   516381.0        NaN
# Mar-17   622161.0        NaN
# Jun-17   669874.0        NaN
# Sep-17  1125414.0        NaN
# Dec-17   820536.0        NaN
# Mar-18   844638.0        NaN
# Jun-18   834414.0        NaN
# Sep-18   819583.0        NaN
# Dec-18   261527.0        NaN
# Mar-19   826225.0        NaN
# Jun-19   968982.0        NaN
# Sep-19        NaN        NaN
#
# [135 rows x 999 columns]

# %%
stocks
# Out:
# ticker         WEGE3         WEGE4
# Date
# Dec-91  5.522262e+01  5.522262e+01
# Mar-92  1.030606e+02  1.030606e+02
# Jun-92  1.844668e+02  1.844668e+02
# Sep-92  3.521265e+02  3.521265e+02
# Dec-92  6.858575e+02  6.858575e+02
# Mar-93  1.488662e+03  1.488662e+03
# Jun-93  3.234225e+03  3.234225e+03
# Sep-93  7.472003e+03  7.472003e+03
# Dec-93  1.942920e+04  1.942920e+04
# Mar-94  5.741367e+04  5.741367e+04
# Jun-94  1.870886e+05  1.870886e+05
# Sep-94  2.132182e+05  2.132182e+05
# Dec-94  2.357480e+05  2.357480e+05
# Mar-95  2.677270e+05  2.677270e+05
# Jun-95  2.964190e+05  2.964190e+05
# Sep-95  3.407340e+05  3.407340e+05
# Dec-95  3.617490e+05  3.617490e+05
# Mar-96  4.086030e+05  4.086030e+05
# Jun-96  4.364540e+05  4.364540e+05
# Sep-96  4.736360e+05  4.736360e+05
# Dec-96  4.948700e+05  4.948700e+05
# Mar-97  5.015860e+05  5.015860e+05
# Jun-97  5.618470e+05  5.618470e+05
# Sep-97  5.853240e+05  5.853240e+05
# Dec-97  6.107730e+05  6.107730e+05
# Mar-98  6.395850e+05  6.395850e+05
# Jun-98  7.000390e+05  7.000390e+05
# Sep-98  7.225200e+05  7.225200e+05
# Dec-98  7.781970e+05  7.781970e+05
# Mar-99  9.161140e+05  9.161140e+05
# ...              ...           ...
# Jun-12  9.109705e+06  9.109705e+06
# Sep-12  8.757033e+06  8.757033e+06
# Dec-12  8.873550e+06  8.873550e+06
# Mar-13  9.496435e+06  9.496435e+06
# Jun-13  9.542922e+06  9.542922e+06
# Sep-13  9.552065e+06  9.552065e+06
# Dec-13  1.014129e+07  1.014129e+07
# Mar-14  9.898693e+06  9.898693e+06
# Jun-14  1.036267e+07  1.036267e+07
# Sep-14  1.090281e+07  1.090281e+07
# Dec-14  1.178263e+07  1.178263e+07
# Mar-15  1.295130e+07  1.295130e+07
# Jun-15  1.312129e+07  1.312129e+07
# Sep-15  1.428992e+07  1.428992e+07
# Dec-15  1.426154e+07  1.426154e+07
# Mar-16  1.345885e+07  1.345885e+07
# Jun-16  1.304868e+07  1.304868e+07
# Sep-16  1.363482e+07  1.363482e+07
# Dec-16  1.350933e+07  1.350933e+07
# Mar-17  1.344603e+07  1.344603e+07
# Jun-17  1.418142e+07  1.418142e+07
# Sep-17  1.396445e+07  1.396445e+07
# Dec-17  1.398599e+07  1.398599e+07
# Mar-18  1.452605e+07  1.452605e+07
# Jun-18  1.546405e+07  1.546405e+07
# Sep-18  1.627413e+07  1.627413e+07
# Dec-18  1.539985e+07  1.539985e+07
# Mar-19  1.522698e+07  1.522698e+07
# Jun-19  1.490781e+07  1.490781e+07
# Sep-19  1.547942e+07  1.547942e+07
#
# [112 rows x 2 columns]

# %%
# queremos remover os vizinhos de NAs coluna a coluna
# estou com o problema de contar o numero máximo de consecutive non NA
# https://stackoverflow.com/questions/41968892/counting-consecutive-numbers-in-a-list
# https://stackoverflow.com/questions/44337512/delete-non-consecutive-values-from-a-dataframe-column
# https://stackoverflow.com/questions/52671308/counting-the-number-of-consecutive-values-that-meets-a-condition-pandas-datafra
# http://blog.adeel.io/2016/10/30/removing-neighboring-consecutive-only-duplicates-in-a-pandas-dataframe/
# talvez a melhor maneira de lidar com um shift seja direto no df, sem passar por series
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.shift.html
# True & False # dá False
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.shift.html
sh_plus = tot_ass.shift(periods=1)
sh_minus = tot_ass.shift(periods=-1)
tot_ass[sh_plus.isnull()&sh_minus.isnull()] = np.NAN

# %%
tot_ass.to_excel("output.xlsx")

# %%
True & False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-195-4af174d2028c> in <module>
# ----> 1 T & F
#
# NameError: name 'T' is not defined

# %%
serie
s_plus = serie.shift()
s_minus = serie.shift(periods=-1)

# periods=1

# %%
s_plus.values == 2
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
# criar df com dictionary e um index e usar expressões lógicas
df1 = pd.DataFrame({'A': [12, 44, 17, 1],
                    'B': [4, 8, 100, -3],
                    'C': [47, 68, 52, 1],
                    'D': [0, 0, 0, 0]},
                    index=[0, 1, 2, 3])
df2 = pd.DataFrame({'A': [1, 2, 3, 4],
                    'B': [-10, 4, 5, 13],
                    'C': [12, 23, 10, 100],
                    'D': [1, 1, 1, 1]},
                    index=[0, 1, 2, 3])
df3 = pd.DataFrame({'A': [1, 2, 3, 4],
                    'B': [-10, np.nan, 5, 13],
                    'C': [np.nan, 23, 10, 100],
                    'D': [1, 1, 1, 1]},
                    index=[0, 1, 2, 3])

# %%
x = df1+df3
x.isna().sum().sum()
# Out:
# 2

# %%
df3.isnull()
# Out:
#        A      B      C      D
# 0   True  False  False  False
# 1  False  False  False  False
# 2  False  False   True  False
# 3  False  False  False  False

# %%
df1&df2
# Out:
#        A      B      C      D
# 0   True  False  False  False
# 1  False  False  False  False
# 2  False  False   True  False
# 3  False  False  False  False

# %%
df1|df2
# Out:
#        A      B     C      D
# 0   True   True  True  False
# 1  False   True  True  False
# 2   True  False  True   True
# 3  False   True  True  False

# %%
ttt = np.NAN
