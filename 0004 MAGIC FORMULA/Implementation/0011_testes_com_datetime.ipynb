# %%
# O objetivo desse estudo é aprender manipulação de datas. Eu já tinha feito alguma coisa com dias úteis na parte de testes
# do hedgepanel. Dá uma olhada. Esses estudos se complementam

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
# Estarei baseando meus estudos em
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html para pandas e
# https://docs.scipy.org/doc/numpy/reference/arrays.datetime.html para numpy
# A questão de datas é misturado pandas com numpy. Pandas usa os tipos básicos do numpy datetime64 and timedelta64 dtypes
# e expande suas funcionalidades
# lembrar que o 64 é porque temos pd.Timedelta e pd.datetime (assim respeitando as maiúsculas e minúsculas)

# %%
# notar como date_range cria um array de datas, embora o formato seja pd.DatetimeIndex, ele usa o datatype
# np.datetime64
# em numpy você cria um array de dates com np.arange('2005-02', '2005-03', dtype='datetime64[D]'), mas em pandas
# acredito que tenha que criar um DatetimeIndex
idx = pd.date_range('2018-01-01', periods=5, freq='H')
idx
# acredito que cada elemento deste array poderia ser criado separadamente com pd.Timestamp
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
# em numpy você cria um array de datas assim. Não dá pra fazer grandes coisas com o array
# notar que aqui são só dates (datas) e não timestamps (date+time)
x = np.arange('2005-02', '2005-03', dtype='datetime64[D]')
x
# Out:
# array(['2005-02-01', '2005-02-02', '2005-02-03', '2005-02-04',
#        '2005-02-05', '2005-02-06', '2005-02-07', '2005-02-08',
#        '2005-02-09', '2005-02-10', '2005-02-11', '2005-02-12',
#        '2005-02-13', '2005-02-14', '2005-02-15', '2005-02-16',
#        '2005-02-17', '2005-02-18', '2005-02-19', '2005-02-20',
#        '2005-02-21', '2005-02-22', '2005-02-23', '2005-02-24',
#        '2005-02-25', '2005-02-26', '2005-02-27', '2005-02-28'],
#       dtype='datetime64[D]')

# %%
print(len(idx))
range(len(idx))
# Qual a diferença entre range() e np.arange? Primeiramente arange é de numpy, enquanto range é da base do python
# arange probably resorts to a native implementation and might be faster therefore. On the other hand, arange returns 
# a full array, which occupies memory, so there might be an overhead. Python 3's range expression is a generator, which 
# does not hold all the values in memory.
# Out:
# 5
# range(0, 5)

# %%
# veja como é fácil fazer resampling
# lembrar que o pd.date_range geralmente é utilizado no index de uma pd.Series ou de um pd.Dataframe, mas ele também pode
# ser usado como o dado as itself.
# Lembrar que se timestamp for usado como index, é corced a Datetimeindex. Algo parecido ocorre com Period
ts = pd.Series(range(len(idx)), index=idx)
print(ts)
# se deixamos ts.resample sem nada, ele retorna um Resampler
x = ts.resample('2H')
# teria que escolher o método de preenchimento. Seja média, ffil, soma dos elementos agrupados, var dos elementos agrupados, etc
x.mean()
# Out:
# 2018-01-01 00:00:00    0
# 2018-01-01 01:00:00    1
# 2018-01-01 02:00:00    2
# 2018-01-01 03:00:00    3
# 2018-01-01 04:00:00    4
# Freq: H, dtype: int64
# 2018-01-01 00:00:00    0.5
# 2018-01-01 02:00:00    2.5
# 2018-01-01 04:00:00    4.0
# Freq: 2H, dtype: float64

# %%
# Pandas geralmente usa 4 conceitos de tempo:
# 1) Date times (pd.Timestamp)
# 2) Time deltas (pd.Timedelta)
# 3) Time spans (pd.Period)
# 4) Date offsets (pd.DateOffset)
# Notar como o nome de Time spans é Period

# 1 2 3 4 5 6 7 8 9
#       x            timestamp 4
#   x - - - - x      Period de 2 a 7

# https://www.geeksforgeeks.org/using-timedelta-and-period-to-create-datetime-based-indexes-in-pandas/
# um time stamp se consiste de vários time periods
# um time delta é bem exato até nos segundos. Um date offset varia de acordo com horário de verão, dias úteis, etc..

# %%
friday = pd.Timestamp('2018-01-05')
friday.day_name() # retorna 'Friday'
saturday = friday + pd.Timedelta('1 day') # retorna Timestamp('2018-01-06 00:00:00')
monday = friday + pd.offsets.BDay() # adiciona 1 business day e retorna Timestamp('2018-01-08 00:00:00')
monday
# Out:
# Timestamp('2018-01-08 00:00:00')

# %%
# Para converter strings e afins para timestamp, usar pd.to_datetime. Dá também para usar contrutor pd.DatetimeIndex. Esses
# métodos suportam format='%Y/%m/%d'. Suportam também o formato de tempo UNIX conhecido como integer or float epoch times

# %%
# Pandas permite criar um range de timestamps
index = pd.date_range(start, end) # usa calendar days, com frequencia diario D
index = pd.bdate_range(start, end) # usa business days, frequencia business day B
# em date_range, dá pra usar o parametro freq= e fazer miséria! Talvez resolva o problema de business end of month day
# freq='BM'
# dá pra usar o parâmetro periods=20 para gerar 20 periodos entre o start e o end

# %%
# Em pandas também temos a opção de gerar ranges usando o parâmetro custom, que permite usar weekmask e holidays. A frequência
# fica como freq="C"

# %% [markdown]
# Date Offset	Frequency String	Description
# DateOffset	None	Generic offset class, defaults to 1 calendar day
# BDay or BusinessDay	'B'	business day (weekday)
# CDay or CustomBusinessDay	'C'	custom business day
# Week	'W'	one week, optionally anchored on a day of the week
# WeekOfMonth	'WOM'	the x-th day of the y-th week of each month
# LastWeekOfMonth	'LWOM'	the x-th day of the last week of each month
# MonthEnd	'M'	calendar month end
# MonthBegin	'MS'	calendar month begin
# BMonthEnd or BusinessMonthEnd	'BM'	business month end
# BMonthBegin or BusinessMonthBegin	'BMS'	business month begin
# CBMonthEnd or CustomBusinessMonthEnd	'CBM'	custom business month end
# CBMonthBegin or CustomBusinessMonthBegin	'CBMS'	custom business month begin
# SemiMonthEnd	'SM'	15th (or other day_of_month) and calendar month end
# SemiMonthBegin	'SMS'	15th (or other day_of_month) and calendar month begin
# QuarterEnd	'Q'	calendar quarter end
# QuarterBegin	'QS'	calendar quarter begin
# BQuarterEnd	'BQ	business quarter end
# BQuarterBegin	'BQS'	business quarter begin
# FY5253Quarter	'REQ'	retail (aka 52-53 week) quarter
# YearEnd	'A'	calendar year end
# YearBegin	'AS' or 'BYS'	calendar year begin
# BYearEnd	'BA'	business year end
# BYearBegin	'BAS'	business year begin
# FY5253	'RE'	retail (aka 52-53 week) year
# Easter	None	Easter holiday
# BusinessHour	'BH'	business hour
# CustomBusinessHour	'CBH'	custom business hour
# Day	'D'	one absolute day
# Hour	'H'	one hour
# Minute	'T' or 'min'	one minute
# Second	'S'	one second
# Milli	'L' or 'ms'	one millisecond
# Micro	'U' or 'us'	one microsecond
# Nano	'N'	one nanosecond

# %%
# DatetimeIndex can be used like a regular index and offers all of its intelligent functionality like selection, slicing, etc.
# Tem maneiras muito inteligentes de parsear Datetimeindex tipo ts['10/31/2011':'12/31/2011']
# ts['2011'] seleciona tudo de 2011, ts['2011-6']

# .dt accessor - Series has an accessor to succinctly return datetime like properties for the values of the Series, if it 
# is a datetime/period like Series. This will return a Series, indexed like the existing Series.
# This enables nice expressions like this: s[s.dt.day == 2]

# %%
# TIMEDELTA vs DATEOFFSET
# Timedelta é em valores absolutos e DateOffset é em valores relativos
# Por isso que para calcular businessdays é utilizado DateOffset

# a Timedelta day will always increment datetimes by 24 hours, while a DateOffset day will increment datetimes to the same 
# time the next day whether a day represents 23, 24 or 25 hours due to daylight savings time

# This particular day contains a day light savings time transition
ts = pd.Timestamp('2016-10-30 00:00:00', tz='Europe/Helsinki')

# Respects absolute time
ts + pd.Timedelta(days=1)
# Out[142]: Timestamp('2016-10-30 23:00:00+0200', tz='Europe/Helsinki')

# Respects calendar time
ts + pd.DateOffset(days=1)
# Out[143]: Timestamp('2016-10-31 00:00:00+0200', tz='Europe/Helsinki')

friday = pd.Timestamp('2018-01-05')

friday.day_name()
# Out[145]: 'Friday'

# Add 2 business days (Friday --> Tuesday)
two_business_days = 2 * pd.offsets.BDay()

two_business_days.apply(friday)
# Out[147]: Timestamp('2018-01-09 00:00:00')

friday + two_business_days
# Out[148]: Timestamp('2018-01-09 00:00:00')

(friday + two_business_days).day_name()
# Out[149]: 'Tuesday'

# %% [markdown]
# Most DateOffsets have associated frequencies strings, or offset aliases, that can be passed into freq keyword arguments. The available date offsets and associated frequency strings can be found below:
#
# Date Offset	Frequency String	Description
# DateOffset	None	Generic offset class, defaults to 1 calendar day
# BDay or BusinessDay	'B'	business day (weekday)
# CDay or CustomBusinessDay	'C'	custom business day
# Week	'W'	one week, optionally anchored on a day of the week
# WeekOfMonth	'WOM'	the x-th day of the y-th week of each month
# LastWeekOfMonth	'LWOM'	the x-th day of the last week of each month
# MonthEnd	'M'	calendar month end
# MonthBegin	'MS'	calendar month begin
# BMonthEnd or BusinessMonthEnd	'BM'	business month end
# BMonthBegin or BusinessMonthBegin	'BMS'	business month begin
# CBMonthEnd or CustomBusinessMonthEnd	'CBM'	custom business month end
# CBMonthBegin or CustomBusinessMonthBegin	'CBMS'	custom business month begin
# SemiMonthEnd	'SM'	15th (or other day_of_month) and calendar month end
# SemiMonthBegin	'SMS'	15th (or other day_of_month) and calendar month begin
# QuarterEnd	'Q'	calendar quarter end
# QuarterBegin	'QS'	calendar quarter begin
# BQuarterEnd	'BQ	business quarter end
# BQuarterBegin	'BQS'	business quarter begin
# FY5253Quarter	'REQ'	retail (aka 52-53 week) quarter
# YearEnd	'A'	calendar year end
# YearBegin	'AS' or 'BYS'	calendar year begin
# BYearEnd	'BA'	business year end
# BYearBegin	'BAS'	business year begin
# FY5253	'RE'	retail (aka 52-53 week) year
# Easter	None	Easter holiday
# BusinessHour	'BH'	business hour
# CustomBusinessHour	'CBH'	custom business hour
# Day	'D'	one absolute day
# Hour	'H'	one hour
# Minute	'T' or 'min'	one minute
# Second	'S'	one second
# Milli	'L' or 'ms'	one millisecond
# Micro	'U' or 'us'	one microsecond
# Nano	'N'	one nanosecond
#
# DateOffsets additionally have rollforward() and rollback() methods. É legal pois além de pular dias não úteis ele também faz offset de horas não úteis

# %%
# Uso de Custom Business Days
weekmask_egypt = 'Sun Mon Tue Wed Thu'

# They also observe International Workers' Day so let's
# add that for a couple of years
holidays = ['2012-05-01',
             dt.datetime(2013, 5, 1),
             np.datetime64('2014-05-01')]

# depois de criado o Custom Business Days tem duas maneiras de usar
bday_egypt = pd.offsets.CustomBusinessDay(holidays=holidays,
                                          weekmask=weekmask_egypt)

dt = dt.datetime(2013, 4, 30)

dt + 2 * bday_egypt # 1 como offset
#Out[189]: Timestamp('2013-05-05 00:00:00')

dts = pd.date_range(dt, periods=5, freq=bday_egypt) # 2 como range. Resulta em um freq='C'

# %%
# dá pra programar holidays e o que acontece se eles caem no sábado e tem que puxar pra sexta (comum nos US?)
# dá pra botar frequência como de 3 em 3 dias úteis
# dr = pd.date_range('1/1/2010', periods=3, freq=3 * pd.offsets.BDay())
# com asfreq() dá pra reescalonar e aumentar ou diminuir dias da frequência
# ts.asfreq(pd.offsets.BDay()) ou ts.asfreq(pd.offsets.BDay(), method='pad')

# transforma de datetimeindex pra array de datetime com to_pydatetime(), mas não sei qual a vantagem ou diferenças
# resampling permite mudar por exemplo de 10 em 10 segundos para 5 mins
# and efficient functionality for performing resampling operations during frequency conversion (e.g., converting secondly
# data into 5-minutely data)
# ts.resample('5Min').sum()
# tem até funções específicas de finance
# ts.resample('5Min').ohlc()
# com resample tem a questão de qual label usar. label specifies whether the result is labeled with the beginning or the
# end of the interval. loffset performs a time adjustment on the output labels. Usar label (index) mais da esquerda ou direita?

# Faltou se aprofundar um pouco em resampling
# Faltou se aprofundar em Periods
# Faltou se aprofundar em Time zone handling
# Out:
# datetime.datetime(2013, 4, 30, 0, 0)

# %%
def org_columns(df):
    '''
    Organiza os dataframes com fundamentos:
        Renomeia columns
        Seleciona apenas tickers de interesse
    '''
    tickers = df.columns.str.extract('(.*)$')[0]
    df.columns = tickers
    on = tickers[tickers.str.contains('.\D3$')]
    pn = tickers[tickers.str.contains('.\D4$')]
    sto_tick = pd.concat([on, pn], ignore_index=True)
    df = df[sto_tick]
    df = df[df.index.str.contains("Mar|Jun|Sep|Dec")]
    df.columns.name = "ticker"
    return df

# %%
# Eliminar ações com volume abaixo de 3 milhões no mês, para isso precisamos do volume mensal. Poderíamos usar volume médio
# Volume Mensal (in thousands)
vm_ati = pd.read_excel('../../data/economatica_1/volume_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
vm_can = pd.read_excel('../../data/economatica_1/volume_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
vm_can.drop(["Jan-86", "Feb-86"], inplace=True)

vm = pd.concat([vm_ati,vm_can],axis=1,sort=False)
vm = org_columns(vm)

# %%
# closing price monthly
cp_mon = pd.read_excel('../../data/economatica_0/close_monthly.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
cp_mon.drop(["Jan-86", "Feb-86"], inplace=True)
cp_mon = org_columns(cp_mon)

# %%
vm
# Out:
# ticker     EALT3      ADHM3     TIET3      AFLT3        BRGE3         CRIV3  \
# Mar-86       NaN        NaN       NaN        NaN          NaN           NaN
# Jun-86       NaN        NaN       NaN        NaN          NaN           NaN
# Sep-86       NaN        NaN       NaN        NaN          NaN           NaN
# Dec-86       NaN        NaN       NaN        NaN          NaN           NaN
# Mar-87       NaN        NaN       NaN        NaN          NaN           NaN
# Jun-87       NaN        NaN       NaN        NaN          NaN           NaN
# Sep-87       NaN        NaN       NaN        NaN          NaN           NaN
# Dec-87       NaN        NaN       NaN        NaN          NaN           NaN
# Mar-88       NaN        NaN       NaN        NaN          NaN           NaN
# Jun-88       NaN        NaN       NaN        NaN          NaN           NaN
# Sep-88       NaN        NaN       NaN        NaN          NaN           NaN
# Dec-88       NaN        NaN       NaN        NaN          NaN           NaN
# Mar-89       NaN        NaN       NaN        NaN          NaN           NaN
# Jun-89       NaN        NaN       NaN        NaN     0.000005  1.281091e-05
# Sep-89       NaN        NaN       NaN        NaN     0.000010  7.043636e-07
# Dec-89       NaN        NaN       NaN        NaN     0.000028  1.893758e-05
# Mar-90       NaN        NaN       NaN        NaN     0.000031  3.374184e-05
# Jun-90       NaN        NaN       NaN        NaN     0.000003  2.142327e-05
# Sep-90       NaN        NaN       NaN        NaN     0.000091  3.610469e-04
# Dec-90       NaN        NaN       NaN        NaN     0.010299  1.030219e-04
# Mar-91       NaN        NaN       NaN        NaN     0.000795  2.232389e-04
# Jun-91       NaN        NaN       NaN        NaN     0.000930  9.114982e-05
# Sep-91       NaN        NaN       NaN        NaN     0.000100  1.698753e-04
# Dec-91       NaN        NaN       NaN        NaN     0.000545  2.565818e-04
# Mar-92       NaN        NaN       NaN        NaN     0.000736  7.704731e-04
# Jun-92       NaN        NaN       NaN        NaN     0.021612  4.838906e-03
# Sep-92       NaN        NaN       NaN        NaN     0.008676  2.316926e-02
# Dec-92       NaN        NaN       NaN        NaN     0.034127  8.305454e-02
# Mar-93       NaN        NaN       NaN        NaN     0.330037  1.048728e-01
# Jun-93       NaN        NaN       NaN        NaN     0.085993  1.701091e-01
# ...          ...        ...       ...        ...          ...           ...
# Jun-12       NaN     13.658       NaN      0.560     8.231000  8.989080e+02
# Sep-12       NaN        NaN       NaN        NaN     4.015000  5.644200e+01
# Dec-12       NaN      2.520       NaN    106.778    55.875000  2.381240e+02
# Mar-13       NaN      0.400       NaN      2.830     2.915000  6.922120e+02
# Jun-13       NaN     17.220       NaN      0.350    47.542000  6.440450e+02
# Sep-13       NaN      1.649       NaN      0.375     8.481000  2.405450e+02
# Dec-13       NaN     12.908       NaN      0.700          NaN  6.840400e+01
# Mar-14       NaN      1.661       NaN      1.626          NaN  1.653270e+03
# Jun-14       NaN  18759.597       NaN     10.500    22.005000  5.530100e+02
# Sep-14    24.502    560.265       NaN     39.009     6.099000  1.672540e+02
# Dec-14    11.500    234.610       NaN      0.750     3.860000  1.065000e+00
# Mar-15       NaN   6833.803       NaN     18.025          NaN  3.116280e+02
# Jun-15       NaN   9150.691       NaN     19.040     1.533000  4.375600e+01
# Sep-15    20.700   1343.156       NaN      1.129     8.400000  5.588500e+01
# Dec-15    20.700     93.770       NaN        NaN          NaN  6.272800e+01
# Mar-16       NaN   1250.307    25.608        NaN     0.391000  9.971000e+00
# Jun-16       NaN   6994.058    21.659        NaN          NaN  4.764630e+02
# Sep-16       NaN  13333.432    58.877    100.002    31.800000  1.242000e+02
# Dec-16       NaN   6967.021   163.489     43.356          NaN  6.803300e+01
# Mar-17       NaN    842.731  8151.093      1.795   101.294000  1.321500e+02
# Jun-17       NaN    798.927  1904.994      8.714    11.020000  3.900000e-01
# Sep-17    27.540    600.531  4127.134      9.557     8.225000  5.521600e+01
# Dec-17       NaN    512.179   956.573     15.341     8.119000  1.885200e+01
# Mar-18       NaN    231.156  1868.008     27.290    53.889000  1.528580e+02
# Jun-18    48.077    195.470   858.766      0.699    41.291000  1.106840e+02
# Sep-18    12.570    294.009  1025.341      1.013   117.535000  1.412918e+03
# Dec-18    20.886    157.836  2074.901     46.116     1.205000  2.138300e+02
# Mar-19     4.664    304.089  3167.503     54.164          NaN  6.361000e+00
# Jun-19    11.324    438.578  2039.048    136.538    10.096000  1.064887e+03
# Sep-19  1169.972   4712.395  3815.873  21857.835  1112.068000  3.751713e+03
#
# ticker         RPAD3         BRIV3       ALSO3  APTI3      ...       VIVO4  \
# Mar-86           NaN  2.021252e-07         NaN    NaN      ...         NaN
# Jun-86           NaN  1.298641e-07         NaN    NaN      ...         NaN
# Sep-86           NaN  7.900364e-08         NaN    NaN      ...         NaN
# Dec-86           NaN  1.099007e-06         NaN    NaN      ...         NaN
# Mar-87           NaN  7.365054e-08         NaN    NaN      ...         NaN
# Jun-87  1.566810e-07  1.835705e-07         NaN    NaN      ...         NaN
# Sep-87  1.926200e-07  8.342663e-07         NaN    NaN      ...         NaN
# Dec-87  1.176149e-07  2.263374e-07         NaN    NaN      ...         NaN
# Mar-88  3.762676e-07  1.906176e-06         NaN    NaN      ...         NaN
# Jun-88  1.165342e-06  9.034684e-07         NaN    NaN      ...         NaN
# Sep-88  1.568956e-06  8.911662e-07         NaN    NaN      ...         NaN
# Dec-88  6.328368e-06  2.186909e-06         NaN    NaN      ...         NaN
# Mar-89  2.705455e-06  2.916431e-06         NaN    NaN      ...         NaN
# Jun-89  3.669824e-06  4.254211e-06         NaN    NaN      ...         NaN
# Sep-89  1.388490e-05  2.542545e-06         NaN    NaN      ...         NaN
# Dec-89  2.228798e-05  5.143716e-05         NaN    NaN      ...         NaN
# Mar-90  2.181819e-05  3.345456e-05         NaN    NaN      ...         NaN
# Jun-90  1.187056e-06  1.643710e-05         NaN    NaN      ...         NaN
# Sep-90  1.454634e-04  3.447188e-04         NaN    NaN      ...         NaN
# Dec-90  4.309984e-03  7.113454e-05         NaN    NaN      ...         NaN
# Mar-91  9.174455e-04  1.133619e-03         NaN    NaN      ...         NaN
# Jun-91  3.235230e-03  2.293462e-03         NaN    NaN      ...         NaN
# Sep-91  2.578018e-04  3.380451e-04         NaN    NaN      ...         NaN
# Dec-91  2.286524e-03  6.290925e-03         NaN    NaN      ...         NaN
# Mar-92  6.989035e-03  2.047100e-02         NaN    NaN      ...         NaN
# Jun-92  7.664177e-03  4.190785e-02         NaN    NaN      ...         NaN
# Sep-92  5.798683e-03  4.663352e-02         NaN    NaN      ...         NaN
# Dec-92  9.153167e-02  2.561999e-01         NaN    NaN      ...         NaN
# Mar-93  5.462036e-01  2.220000e-01         NaN    NaN      ...         NaN
# Jun-93  3.389495e-01  3.302560e-01         NaN    NaN      ...         NaN
# ...              ...           ...         ...    ...      ...         ...
# Jun-12  1.033840e+02  2.597140e+02   78352.791    NaN      ...         NaN
# Sep-12  4.000000e-01  1.541130e+02   78311.985    NaN      ...         NaN
# Dec-12  6.544000e+00  9.525200e+01   96421.503    NaN      ...         NaN
# Mar-13  4.030000e+00  7.073280e+02   99759.489    NaN      ...         NaN
# Jun-13  2.104800e+01  7.172860e+02   60709.639    NaN      ...         NaN
# Sep-13  3.909000e+00  1.130400e+01   72909.629    NaN      ...         NaN
# Dec-13  1.359000e+00  2.196640e+02   23840.274    NaN      ...         NaN
# Mar-14  3.030000e-01  5.047200e+01   59344.788    NaN      ...         NaN
# Jun-14  1.836000e+01  1.725120e+02   29996.608    NaN      ...         NaN
# Sep-14  2.803700e+01  1.583090e+02   36488.547    NaN      ...         NaN
# Dec-14  2.080000e-01  1.385400e+01   13258.661    NaN      ...         NaN
# Mar-15           NaN  6.556000e+00   14005.207    NaN      ...         NaN
# Jun-15  4.500000e-01  2.569340e+02   16572.778    NaN      ...         NaN
# Sep-15  3.433000e+00  7.620700e+01   12643.818    NaN      ...         NaN
# Dec-15  1.848000e+00  3.111500e+01   12369.392    NaN      ...         NaN
# Mar-16  2.527000e+00  1.124000e+01   63748.517    NaN      ...         NaN
# Jun-16           NaN  9.663100e+01   12455.861    NaN      ...         NaN
# Sep-16  3.630100e+01  5.587100e+01  102215.412    NaN      ...         NaN
# Dec-16           NaN  2.120600e+01   21019.416    NaN      ...         NaN
# Mar-17  5.754300e+01  2.730670e+02   89440.791    NaN      ...         NaN
# Jun-17  2.390000e-01  3.670000e+01   24793.675    NaN      ...         NaN
# Sep-17  3.883000e+00  2.349810e+02   64715.987    NaN      ...         NaN
# Dec-17  1.380000e+01  5.175470e+02   15721.130    NaN      ...         NaN
# Mar-18           NaN  5.270530e+02   22025.829    NaN      ...         NaN
# Jun-18  4.400000e-01  1.300500e+02   12576.279    NaN      ...         NaN
# Sep-18  8.524800e+01  7.003700e+02    4918.005    NaN      ...         NaN
# Dec-18  3.467000e+00  1.191500e+01    8473.117    NaN      ...         NaN
# Mar-19  4.816000e+00  2.420110e+02   13427.655    NaN      ...         NaN
# Jun-19  1.337600e+02  4.841140e+02   15724.597    NaN      ...         NaN
# Sep-19  6.647870e+02  6.050900e+02  636383.210    NaN      ...         NaN
#
# ticker         VTEC4         VULC4      WEGE4         WMBY4  WET4      WISA4  \
# Mar-86           NaN  2.174527e-06        NaN  1.168935e-05   NaN        NaN
# Jun-86           NaN  5.368808e-07   0.000021  1.091755e-05   NaN        NaN
# Sep-86           NaN  3.141345e-07   0.000006  4.285257e-06   NaN        NaN
# Dec-86           NaN  2.069063e-08   0.000001  2.374025e-06   NaN        NaN
# Mar-87           NaN  4.002121e-08   0.000006  7.027429e-07   NaN        NaN
# Jun-87           NaN  4.980876e-06   0.000022  9.286172e-06   NaN        NaN
# Sep-87           NaN  3.730049e-06   0.000017  4.081276e-06   NaN        NaN
# Dec-87           NaN  1.704742e-06   0.000007  2.625647e-06   NaN        NaN
# Mar-88           NaN  9.542665e-07   0.000115  1.795613e-05   NaN        NaN
# Jun-88  9.765229e-07  1.186199e-05   0.000155  1.297281e-05   NaN        NaN
# Sep-88  1.923069e-07  1.205547e-05   0.000148  4.589003e-05   NaN        NaN
# Dec-88  2.922625e-07  3.543084e-05   0.000258  7.886895e-05   NaN        NaN
# Mar-89  3.631200e-07  4.341633e-05   0.000351  9.146280e-05   NaN        NaN
# Jun-89  8.675789e-06  9.895829e-05   0.000049  1.179356e-05   NaN        NaN
# Sep-89  8.156983e-05  6.916984e-05   0.002556  2.670790e-04   NaN        NaN
# Dec-89  3.859810e-04  5.755185e-04   0.005264  5.435343e-04   NaN        NaN
# Mar-90  2.186039e-04  1.134327e-03   0.011797  1.236053e-04   NaN        NaN
# Jun-90  4.839254e-05  6.153636e-04   0.001678  1.386437e-03   NaN        NaN
# Sep-90  1.431657e-05  3.892160e-03   0.012106  5.530673e-05   NaN   0.000233
# Dec-90  3.792192e-05  3.692525e-03   0.004906  1.381648e-04   NaN   0.000057
# Mar-91  1.531554e-05  4.101200e-03   0.023119  6.355317e-04   NaN   0.000116
# Jun-91  9.631179e-05  3.153328e-02   0.016821  9.710397e-03   NaN   0.000825
# Sep-91  1.077750e-03  1.008102e-02   0.020316  1.970273e-03   NaN   0.000140
# Dec-91  3.731811e-05  1.449091e-04   0.129700  1.574745e-03   NaN   0.000016
# Mar-92  3.762644e-04  7.209545e-02   0.148428  7.818116e-03   NaN   0.043440
# Jun-92  4.077286e-04  3.015246e-03   0.883233  5.866182e-04   NaN   0.000028
# Sep-92  3.652247e-04           NaN   0.093934  4.827782e-03   NaN        NaN
# Dec-92  1.323085e-02  9.106218e-03   3.051175  1.545458e-01   NaN        NaN
# Mar-93  4.568909e-03  1.254560e-03   1.484842  2.573347e+00   NaN   0.005117
# Jun-93  6.804044e-02  8.979041e-01  29.997019  1.571360e-01   NaN   0.101700
# ...              ...           ...        ...           ...   ...        ...
# Jun-12           NaN           NaN        NaN           NaN   NaN  29.010000
# Sep-12           NaN           NaN        NaN           NaN   NaN        NaN
# Dec-12           NaN           NaN        NaN           NaN   NaN        NaN
# Mar-13           NaN           NaN        NaN           NaN   NaN        NaN
# Jun-13           NaN           NaN        NaN           NaN   NaN        NaN
# Sep-13           NaN           NaN        NaN           NaN   NaN        NaN
# Dec-13           NaN           NaN        NaN           NaN   NaN        NaN
# Mar-14           NaN           NaN        NaN           NaN   NaN        NaN
# Jun-14           NaN           NaN        NaN           NaN   NaN        NaN
# Sep-14           NaN           NaN        NaN           NaN   NaN        NaN
# Dec-14           NaN           NaN        NaN           NaN   NaN        NaN
# Mar-15           NaN           NaN        NaN           NaN   NaN        NaN
# Jun-15           NaN           NaN        NaN           NaN   NaN        NaN
# Sep-15           NaN           NaN        NaN           NaN   NaN        NaN
# Dec-15           NaN           NaN        NaN           NaN   NaN        NaN
# Mar-16           NaN           NaN        NaN           NaN   NaN        NaN
# Jun-16           NaN           NaN        NaN           NaN   NaN        NaN
# Sep-16           NaN           NaN        NaN           NaN   NaN        NaN
# Dec-16           NaN           NaN        NaN           NaN   NaN        NaN
# Mar-17           NaN           NaN        NaN           NaN   NaN        NaN
# Jun-17           NaN           NaN        NaN           NaN   NaN        NaN
# Sep-17           NaN           NaN        NaN           NaN   NaN        NaN
# Dec-17           NaN           NaN        NaN           NaN   NaN        NaN
# Mar-18           NaN           NaN        NaN           NaN   NaN        NaN
# Jun-18           NaN           NaN        NaN           NaN   NaN        NaN
# Sep-18           NaN           NaN        NaN           NaN   NaN        NaN
# Dec-18           NaN           NaN        NaN           NaN   NaN        NaN
# Mar-19           NaN           NaN        NaN           NaN   NaN        NaN
# Jun-19           NaN           NaN        NaN           NaN   NaN        NaN
# Sep-19           NaN           NaN        NaN           NaN   NaN        NaN
#
# ticker         ILMD4  ESTC4         ZIVI4
# Mar-86  7.927801e-07    NaN           NaN
# Jun-86  1.186296e-05    NaN           NaN
# Sep-86  3.327951e-06    NaN           NaN
# Dec-86  2.484352e-06    NaN           NaN
# Mar-87  1.758215e-06    NaN           NaN
# Jun-87  4.225760e-06    NaN  2.011705e-06
# Sep-87  1.074898e-05    NaN  6.912728e-07
# Dec-87  2.576203e-06    NaN  6.542720e-07
# Mar-88  7.956805e-06    NaN  7.349243e-06
# Jun-88  3.421331e-05    NaN  2.632411e-05
# Sep-88  5.188847e-05    NaN  5.546745e-05
# Dec-88  2.674192e-05    NaN  1.171189e-05
# Mar-89  2.970806e-05    NaN  6.253691e-05
# Jun-89  1.525064e-04    NaN  2.260070e-04
# Sep-89  3.008188e-04    NaN  2.031765e-03
# Dec-89  1.173603e-04    NaN  1.142796e-03
# Mar-90  3.801241e-04    NaN  1.352859e-03
# Jun-90  6.487271e-04    NaN  7.565854e-04
# Sep-90  2.163550e-03    NaN  5.664348e-04
# Dec-90  7.326371e-04    NaN  4.631554e-04
# Mar-91  2.451267e-03    NaN  5.922197e-04
# Jun-91  3.893635e-03    NaN  3.986789e-03
# Sep-91  8.305196e-04    NaN  4.580238e-03
# Dec-91  6.049560e-04    NaN  1.684779e-03
# Mar-92  2.652749e-03    NaN  2.138428e-02
# Jun-92  1.481807e-02    NaN  1.523378e-02
# Sep-92  5.373762e-02    NaN  3.224701e-03
# Dec-92  3.850257e-02    NaN  1.587607e-02
# Mar-93  7.816145e-01    NaN  7.716154e-01
# Jun-93  2.017081e+00    NaN  1.735065e-01
# ...              ...    ...           ...
# Jun-12           NaN    NaN           NaN
# Sep-12           NaN    NaN           NaN
# Dec-12           NaN    NaN           NaN
# Mar-13           NaN    NaN           NaN
# Jun-13           NaN    NaN           NaN
# Sep-13           NaN    NaN           NaN
# Dec-13           NaN    NaN           NaN
# Mar-14           NaN    NaN           NaN
# Jun-14           NaN    NaN           NaN
# Sep-14           NaN    NaN           NaN
# Dec-14           NaN    NaN           NaN
# Mar-15           NaN    NaN           NaN
# Jun-15           NaN    NaN           NaN
# Sep-15           NaN    NaN           NaN
# Dec-15           NaN    NaN           NaN
# Mar-16           NaN    NaN           NaN
# Jun-16           NaN    NaN           NaN
# Sep-16           NaN    NaN           NaN
# Dec-16           NaN    NaN           NaN
# Mar-17           NaN    NaN           NaN
# Jun-17           NaN    NaN           NaN
# Sep-17           NaN    NaN           NaN
# Dec-17           NaN    NaN           NaN
# Mar-18           NaN    NaN           NaN
# Jun-18           NaN    NaN           NaN
# Sep-18           NaN    NaN           NaN
# Dec-18           NaN    NaN           NaN
# Mar-19           NaN    NaN           NaN
# Jun-19           NaN    NaN           NaN
# Sep-19           NaN    NaN           NaN
#
# [135 rows x 998 columns]

# %%
cp_mon
# Out:
# ticker  APPA3  ABYA3         AVIL3      ADHM3      AELP3  AESL3      GETI3  \
# Date
# Mar-86    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Jun-86    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Sep-86    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Dec-86    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Mar-87    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Jun-87    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Sep-87    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Dec-87    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Mar-88    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Jun-88    NaN    NaN  3.971664e-08        NaN        NaN    NaN        NaN
# Sep-88    NaN    NaN  8.077960e-08        NaN        NaN    NaN        NaN
# Dec-88    NaN    NaN  7.035409e-08        NaN        NaN    NaN        NaN
# Mar-89    NaN    NaN  1.304846e-07        NaN        NaN    NaN        NaN
# Jun-89    NaN    NaN  7.432464e-07        NaN        NaN    NaN        NaN
# Sep-89    NaN    NaN  1.278520e-06        NaN        NaN    NaN        NaN
# Dec-89    NaN    NaN  3.874303e-06        NaN        NaN    NaN        NaN
# Mar-90    NaN    NaN  1.318010e-05        NaN        NaN    NaN        NaN
# Jun-90    NaN    NaN  3.630446e-06        NaN        NaN    NaN        NaN
# Sep-90    NaN    NaN  5.960744e-06        NaN        NaN    NaN        NaN
# Dec-90    NaN    NaN  2.554605e-06        NaN        NaN    NaN        NaN
# Mar-91    NaN    NaN  5.705284e-06        NaN        NaN    NaN        NaN
# Jun-91    NaN    NaN  9.366883e-06        NaN        NaN    NaN        NaN
# Sep-91    NaN    NaN  1.021842e-05        NaN        NaN    NaN        NaN
# Dec-91    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Mar-92    NaN    NaN  1.606695e-05        NaN        NaN    NaN        NaN
# Jun-92    NaN    NaN  5.355651e-05        NaN        NaN    NaN        NaN
# Sep-92    NaN    NaN  6.248260e-05        NaN        NaN    NaN        NaN
# Dec-92    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Mar-93    NaN    NaN           NaN        NaN        NaN    NaN        NaN
# Jun-93    NaN    NaN  1.393650e-03        NaN        NaN    NaN        NaN
# ...       ...    ...           ...        ...        ...    ...        ...
# Sep-11    NaN    NaN           NaN  57.014935  44.124215    NaN  13.664457
# Dec-11    NaN    NaN           NaN  60.015721  41.193172    NaN  15.602591
# Mar-12    NaN    NaN           NaN  59.865681  33.805561    NaN  16.810405
# Jun-12    NaN    NaN           NaN  59.715642  23.240677    NaN  17.265573
# Sep-12    NaN    NaN           NaN        NaN  16.844509    NaN  13.135344
# Dec-12    NaN    NaN           NaN  66.017293  13.826732    NaN  15.550766
# Mar-13    NaN    NaN           NaN  60.015721   9.442415    NaN  13.299929
# Jun-13    NaN    NaN           NaN  22.505895   7.591891    NaN  15.807585
# Sep-13    NaN    NaN           NaN  22.355856  10.324972    NaN  15.985066
# Dec-13    NaN    NaN           NaN  13.053419   8.819555    NaN  14.840279
# Mar-14    NaN    NaN           NaN  15.003930   7.111005    NaN  13.172832
# Jun-14    NaN    NaN           NaN   7.051847   8.039628    NaN  14.663832
# Sep-14    NaN    NaN           NaN   4.651218   7.458450    NaN  15.392134
# Dec-14    NaN    NaN           NaN   3.150825   9.220995    NaN  14.739193
# Mar-15    NaN    NaN           NaN   5.551454   8.184374    NaN  14.067047
# Jun-15    NaN    NaN           NaN   5.851533  11.254748    NaN  16.272435
# Sep-15    NaN    NaN           NaN   2.889531   6.535652    NaN  14.070000
# Dec-15    NaN    NaN           NaN   1.926354   5.587884    NaN  14.450000
# Mar-16    NaN    NaN           NaN   3.210590   9.773860    NaN        NaN
# Jun-16    NaN    NaN           NaN   9.024827   9.090000    NaN        NaN
# Sep-16    NaN    NaN           NaN   6.960000  11.950000    NaN        NaN
# Dec-16    NaN    NaN           NaN   3.160000  13.010000    NaN        NaN
# Mar-17    NaN    NaN           NaN   2.880000        NaN    NaN        NaN
# Jun-17    NaN    NaN           NaN   2.050000   7.490000    NaN        NaN
# Sep-17    NaN    NaN           NaN   2.070000   6.000000    NaN        NaN
# Dec-17    NaN    NaN           NaN   2.040000   5.010000    NaN        NaN
# Mar-18    NaN    NaN           NaN   1.770000   2.340000    NaN        NaN
# Jun-18    NaN    NaN           NaN   1.600000   1.440000    NaN        NaN
# Sep-18    NaN    NaN           NaN   1.700000   1.930000    NaN        NaN
# Dec-18    NaN    NaN           NaN   1.500000        NaN    NaN        NaN
#
# ticker  AETA3     AFLT3         BSGR3      ...       VPSC4  VPTA4  \
# Date                                       ...
# Mar-86    NaN       NaN           NaN      ...         NaN    NaN
# Jun-86    NaN       NaN           NaN      ...         NaN    NaN
# Sep-86    NaN       NaN           NaN      ...         NaN    NaN
# Dec-86    NaN       NaN           NaN      ...         NaN    NaN
# Mar-87    NaN       NaN           NaN      ...         NaN    NaN
# Jun-87    NaN       NaN           NaN      ...         NaN    NaN
# Sep-87    NaN       NaN           NaN      ...         NaN    NaN
# Dec-87    NaN       NaN           NaN      ...         NaN    NaN
# Mar-88    NaN       NaN           NaN      ...         NaN    NaN
# Jun-88    NaN       NaN           NaN      ...         NaN    NaN
# Sep-88    NaN       NaN           NaN      ...         NaN    NaN
# Dec-88    NaN       NaN           NaN      ...         NaN    NaN
# Mar-89    NaN       NaN           NaN      ...         NaN    NaN
# Jun-89    NaN       NaN  1.397862e-08      ...         NaN    NaN
# Sep-89    NaN       NaN  6.989308e-08      ...         NaN    NaN
# Dec-89    NaN       NaN           NaN      ...         NaN    NaN
# Mar-90    NaN       NaN           NaN      ...         NaN    NaN
# Jun-90    NaN       NaN           NaN      ...         NaN    NaN
# Sep-90    NaN       NaN  1.932337e-07      ...         NaN    NaN
# Dec-90    NaN       NaN           NaN      ...         NaN    NaN
# Mar-91    NaN       NaN  1.288225e-06      ...         NaN    NaN
# Jun-91    NaN       NaN  3.059534e-06      ...         NaN    NaN
# Sep-91    NaN       NaN  1.964543e-05      ...         NaN    NaN
# Dec-91    NaN       NaN  3.220562e-05      ...         NaN    NaN
# Mar-92    NaN       NaN  3.542618e-05      ...         NaN    NaN
# Jun-92    NaN       NaN  9.661685e-05      ...         NaN    NaN
# Sep-92    NaN       NaN  2.528141e-04      ...         NaN    NaN
# Dec-92    NaN       NaN  4.669815e-04      ...         NaN    NaN
# Mar-93    NaN       NaN           NaN      ...         NaN    NaN
# Jun-93    NaN       NaN  1.660684e-03      ...         NaN    NaN
# ...       ...       ...           ...      ...         ...    ...
# Sep-11    NaN  1.831488           NaN      ...         NaN    NaN
# Dec-11    NaN  1.831488           NaN      ...         NaN    NaN
# Mar-12    NaN  2.564084           NaN      ...         NaN    NaN
# Jun-12    NaN  3.121694           NaN      ...         NaN    NaN
# Sep-12    NaN       NaN           NaN      ...         NaN    NaN
# Dec-12    NaN  1.672336           NaN      ...         NaN    NaN
# Mar-13    NaN  2.006803           NaN      ...         NaN    NaN
# Jun-13    NaN  2.106986           NaN      ...         NaN    NaN
# Sep-13    NaN  2.346792           NaN      ...         NaN    NaN
# Dec-13    NaN  2.190340           NaN      ...         NaN    NaN
# Mar-14    NaN  1.877434           NaN      ...         NaN    NaN
# Jun-14    NaN  1.976289           NaN      ...         NaN    NaN
# Sep-14    NaN  1.811598           NaN      ...         NaN    NaN
# Dec-14    NaN  1.709662           NaN      ...         NaN    NaN
# Mar-15    NaN  1.846435           NaN      ...         NaN    NaN
# Jun-15    NaN  1.940765           NaN      ...         NaN    NaN
# Sep-15    NaN  1.605412           NaN      ...         NaN    NaN
# Dec-15    NaN       NaN           NaN      ...         NaN    NaN
# Mar-16    NaN       NaN           NaN      ...         NaN    NaN
# Jun-16    NaN       NaN           NaN      ...         NaN    NaN
# Sep-16    NaN  2.357406           NaN      ...         NaN    NaN
# Dec-16    NaN  2.498023           NaN      ...         NaN    NaN
# Mar-17    NaN  3.697406           NaN      ...         NaN    NaN
# Jun-17    NaN  3.638671           NaN      ...         NaN    NaN
# Sep-17    NaN  5.116881           NaN      ...         NaN    NaN
# Dec-17    NaN  4.818545           NaN      ...         NaN    NaN
# Mar-18    NaN  6.495825           NaN      ...         NaN    NaN
# Jun-18    NaN  6.854881           NaN      ...         NaN    NaN
# Sep-18    NaN  4.913155           NaN      ...         NaN    NaN
# Dec-18    NaN  5.550000           NaN      ...         NaN    NaN
#
# ticker         VGOR4         VTEC4  WET4         MWET4         WHRL4  \
# Date
# Mar-86           NaN           NaN   NaN           NaN           NaN
# Jun-86           NaN           NaN   NaN           NaN           NaN
# Sep-86           NaN           NaN   NaN           NaN  3.173499e-10
# Dec-86           NaN           NaN   NaN           NaN  2.167268e-10
# Mar-87           NaN           NaN   NaN           NaN  1.238439e-10
# Jun-87  1.945431e-10           NaN   NaN  3.216852e-07  3.096097e-10
# Sep-87  2.804453e-10           NaN   NaN  3.666265e-07  5.275530e-10
# Dec-87  2.273880e-10           NaN   NaN  1.892266e-07  6.234718e-10
# Mar-88  1.288532e-09           NaN   NaN  1.123533e-06  1.480849e-09
# Jun-88  1.354662e-09  3.761756e-12   NaN  2.351345e-06  1.742175e-09
# Sep-88  2.351489e-09  2.664577e-12   NaN  4.709395e-06  4.092100e-09
# Dec-88  5.111932e-09  2.194357e-12   NaN  5.886743e-06  1.156464e-08
# Mar-89  4.242903e-09  3.134796e-12   NaN  7.456541e-06  1.922469e-08
# Jun-89  6.570275e-09  2.852665e-11   NaN  9.916413e-06  3.661845e-08
# Sep-89  1.816488e-08  1.963636e-10   NaN  4.707792e-06  1.204198e-07
# Dec-89  4.251355e-08  8.727273e-10   NaN  1.428571e-05  1.945242e-07
# Mar-90  2.324100e-07  7.272728e-10   NaN  1.883117e-05  2.714023e-07
# Jun-90  5.153157e-07  1.454546e-09   NaN  1.038961e-05  4.853927e-07
# Sep-90  4.925940e-07  8.727273e-10   NaN  1.298701e-05  8.049911e-07
# Dec-90  5.703721e-07  6.036363e-10   NaN  7.467532e-06  1.207405e-06
# Mar-91  9.333361e-07  7.818182e-10   NaN  2.922078e-05  2.779541e-06
# Jun-91  1.632093e-06  1.090909e-09   NaN  6.493507e-05  9.646643e-06
# Sep-91  2.158574e-06  2.981818e-09   NaN  5.519481e-05  2.037436e-05
# Dec-91  2.895648e-06  2.181818e-09   NaN  5.519481e-05  1.811666e-05
# Mar-92  1.289880e-05  7.272727e-09   NaN  3.246753e-04  3.602869e-05
# Jun-92  2.895648e-05  1.091273e-08   NaN  1.461039e-04  6.928539e-05
# Sep-92  7.897222e-05  1.272727e-08   NaN  3.084416e-04  1.117780e-04
# Dec-92  1.110876e-04  7.272727e-08   NaN  1.623377e-04  2.794445e-04
# Mar-93  2.764028e-04  1.818182e-07   NaN  3.246753e-03  8.147951e-04
# Jun-93  4.459435e-04  5.854546e-07   NaN  1.623377e-02  2.086327e-03
# ...              ...           ...   ...           ...           ...
# Sep-11           NaN           NaN   NaN  2.300000e+01  1.860687e+00
# Dec-11           NaN           NaN   NaN  1.870000e+01  1.905712e+00
# Mar-12           NaN           NaN   NaN  1.500000e+01  2.079980e+00
# Jun-12           NaN           NaN   NaN  1.140000e+01  1.855118e+00
# Sep-12           NaN           NaN   NaN  1.170000e+01  1.866361e+00
# Dec-12           NaN           NaN   NaN  9.400000e+00  2.002740e+00
# Mar-13           NaN           NaN   NaN  9.400000e+00  2.383926e+00
# Jun-13           NaN           NaN   NaN  9.500000e+00  2.504937e+00
# Sep-13           NaN           NaN   NaN  1.380000e+01  2.650151e+00
# Dec-13           NaN           NaN   NaN  1.710000e+01  2.753529e+00
# Mar-14           NaN           NaN   NaN  1.510000e+01  2.627767e+00
# Jun-14           NaN           NaN   NaN  1.180000e+01  3.050289e+00
# Sep-14           NaN           NaN   NaN  7.900000e+00  2.962511e+00
# Dec-14           NaN           NaN   NaN  5.000000e+00  3.210363e+00
# Mar-15           NaN           NaN   NaN  3.900000e+00  2.999048e+00
# Jun-15           NaN           NaN   NaN  4.200000e+00  2.828370e+00
# Sep-15           NaN           NaN   NaN  3.000000e+00  2.300083e+00
# Dec-15           NaN           NaN   NaN  1.320000e+00  2.011157e+00
# Mar-16           NaN           NaN   NaN  1.900000e+00  2.053947e+00
# Jun-16           NaN           NaN   NaN  1.610000e+00  2.216552e+00
# Sep-16           NaN           NaN   NaN  2.350000e+00  2.901201e+00
# Dec-16           NaN           NaN   NaN  1.520000e+00  2.730038e+00
# Mar-17           NaN           NaN   NaN  2.250000e+00  2.935433e+00
# Jun-17           NaN           NaN   NaN  2.620000e+00  2.966656e+00
# Sep-17           NaN           NaN   NaN  2.570000e+00  3.647044e+00
# Dec-17           NaN           NaN   NaN  2.670000e+00  4.833779e+00
# Mar-18           NaN           NaN   NaN  2.500000e+00  5.260004e+00
# Jun-18           NaN           NaN   NaN  2.400000e+00  5.327813e+00
# Sep-18           NaN           NaN   NaN  2.500000e+00  5.424682e+00
# Dec-18           NaN           NaN   NaN  2.960000e+00  5.100000e+00
#
# ticker         WLMM4         ILMD4         ZIVI4
# Date
# Mar-86  4.056327e-09  8.749650e-08           NaN
# Jun-86  2.761990e-09  1.698899e-07           NaN
# Sep-86  1.216898e-09  9.213262e-08           NaN
# Dec-86  8.112654e-10  7.841075e-08           NaN
# Mar-87  5.936988e-10  7.187651e-08           NaN
# Jun-87  1.438152e-09  1.128640e-07  6.165559e-09
# Sep-87  1.253774e-09  1.551879e-07  9.248338e-09
# Dec-87  1.307841e-09  9.522896e-08  5.240725e-09
# Mar-88  3.966713e-09  1.798769e-07  2.157946e-08
# Jun-88  9.291357e-09  5.264177e-07  4.501236e-08
# Sep-88  1.995524e-08  7.896265e-07  5.436303e-08
# Dec-88  4.270909e-08  6.053803e-07  5.860411e-08
# Mar-89  1.576951e-07  7.896265e-07  7.711068e-08
# Jun-89  3.440165e-07  2.288510e-06  2.188887e-07
# Sep-89  6.708321e-07  5.384730e-06  8.950118e-07
# Dec-89  7.998383e-07  5.250112e-06  2.042962e-06
# Mar-90  4.472214e-06  1.911310e-05  9.120364e-07
# Jun-90  3.483167e-06  2.423129e-05  2.863717e-06
# Sep-90  3.527029e-06  2.153892e-05  2.306883e-06
# Dec-90  4.730226e-06  3.230838e-05  1.638682e-06
# Mar-91  1.066451e-05  5.788585e-05  2.108014e-06
# Jun-91  2.203252e-05  1.913950e-04  5.811224e-06
# Sep-91  2.575050e-05  1.266152e-04  1.452806e-05
# Dec-91  2.434593e-05  2.650084e-04  1.654585e-05
# Mar-92  1.198569e-04  1.177815e-03  6.860473e-05
# Jun-92  1.947674e-04  1.531160e-03  4.681264e-05
# Sep-92  2.172406e-04  3.238992e-03  9.362527e-05
# Dec-92  3.745527e-04  6.477984e-03  1.444735e-04
# Mar-93  1.048748e-03  2.002286e-02  1.049249e-03
# Jun-93  1.310935e-03  5.005715e-02  1.307525e-03
# ...              ...           ...           ...
# Sep-11           NaN  2.550000e+01           NaN
# Dec-11  8.216942e+00           NaN           NaN
# Mar-12           NaN           NaN           NaN
# Jun-12           NaN           NaN           NaN
# Sep-12  9.411176e+00           NaN           NaN
# Dec-12  9.858867e+00           NaN           NaN
# Mar-13  1.073977e+01           NaN           NaN
# Jun-13  8.050548e+00           NaN           NaN
# Sep-13  8.544728e+00           NaN           NaN
# Dec-13  9.249914e+00           NaN           NaN
# Mar-14  1.056564e+01           NaN           NaN
# Jun-14  1.054494e+01           NaN           NaN
# Sep-14  1.002420e+01           NaN           NaN
# Dec-14  1.106568e+01           NaN           NaN
# Mar-15  7.876159e+00           NaN           NaN
# Jun-15           NaN           NaN           NaN
# Sep-15  6.787523e+00           NaN           NaN
# Dec-15  3.745405e+00           NaN           NaN
# Mar-16  1.797795e+00           NaN           NaN
# Jun-16  2.320000e+00           NaN           NaN
# Sep-16  2.970000e+00           NaN           NaN
# Dec-16  2.600000e+00           NaN           NaN
# Mar-17  2.670000e+00           NaN           NaN
# Jun-17  3.350000e+00           NaN           NaN
# Sep-17  5.250000e+00           NaN           NaN
# Dec-17  5.250000e+00           NaN           NaN
# Mar-18  6.030000e+00           NaN           NaN
# Jun-18  5.400000e+00           NaN           NaN
# Sep-18  4.780000e+00           NaN           NaN
# Dec-18  5.070000e+00           NaN           NaN
#
# [132 rows x 639 columns]

# %%
# EBIT
ebit_ati = pd.read_excel('../../data/economatica_1/ebit_mensal__ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ebit_can = pd.read_excel('../../data/economatica_1/ebit_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ebit_can.drop(["Jan-86", "Feb-86"], inplace=True)

ebit = pd.concat([ebit_ati,ebit_can],axis=1,sort=False)
ebit = org_columns(ebit)

# %%
# Net Working Capital
nwc_ati = pd.read_excel('../../data/economatica_1/working_capital_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
nwc_can = pd.read_excel('../../data/economatica_1/working_capital_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
nwc_can.drop(["Jan-86", "Feb-86"], inplace=True)

nwc = pd.concat([ebit_ati,ebit_can],axis=1,sort=False)
nwc = org_columns(nwc)

# %%
# Total Assets
ta_ati = pd.read_excel('../../data/economatica_1/total_assets_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ta_can = pd.read_excel('../../data/economatica_1/total_assets_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ta_can.drop(["Jan-86", "Feb-86"], inplace=True)

ta = pd.concat([ta_ati,ta_can],axis=1,sort=False)
ta = org_columns(ta)

# %%
# Ativo Circulante
ac_ati = pd.read_excel('../../data/economatica_1/ativo_circulante_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ac_can = pd.read_excel('../../data/economatica_1/ativo_circulante_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
ac_can.drop(["Jan-86", "Feb-86"], inplace=True)

ac = pd.concat([ac_ati,ac_can],axis=1,sort=False)
ac = org_columns(ac)

# %%
# Passivo Circulante
pc_ati = pd.read_excel('../../data/economatica_1/passivo_circulante_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
pc_can = pd.read_excel('../../data/economatica_1/passivo_circulante_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
pc_can.drop(["Jan-86", "Feb-86"], inplace=True)

pc = pd.concat([pc_ati,pc_can],axis=1,sort=False)
pc = org_columns(pc)

# %%
# Total Current Assets
# tca não perdeu nada nessa operação quanto ao não uso de fill_value em relação a ac-pc
# lembrar que nessas operações o número de colunas vai ser o maior possível, tipo com concatenar
# tca = ac - pc
tca = ac.sub(pc,fill_value=0)

# %%
# Goodwill
gw_ati = pd.read_excel('../../data/economatica_1/goodwill_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
gw_can = pd.read_excel('../../data/economatica_1/goodwill_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
# pc_can.drop(["Jan-86", "Feb-86"], inplace=True)

gw = pd.concat([gw_ati,gw_can],axis=1,sort=False)
gw = org_columns(gw)

# %%
# Net Fixed Assets
# nfa = ta - tca - gw
# lembrar que a ordem de precedência é a sub tca e só depois a sub gw
# nfa2 = ta.sub(tca, fill_value=0).sub(gw, fill_value=0)
# nfa.equals(nfa2) # vai dar False pois devem ser diferentes

nfa = ta.sub(tca, fill_value=0).sub(gw, fill_value=0)

# %%
# Market Value of Equity
mve_ati = pd.read_excel('../../data/economatica_1/valor_mercado_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
mve_can = pd.read_excel('../../data/economatica_1/valor_mercado_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
mve_can.drop(["Jan-86", "Feb-86"], inplace=True)

mve = pd.concat([mve_ati,mve_can],axis=1,sort=False)
mve = org_columns(mve)

# %%
# Net Interest-Bearing Debt
nibd_ati = pd.read_excel('../../data/economatica_1/net_debt_mensal_ativas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
nibd_can = pd.read_excel('../../data/economatica_1/net_debt_mensal_canceladas.xlsx',
                            skiprows = [1,2],
                            header=1,
                            index_col = 0,
                            na_values='-')
nibd_can.drop(["Jan-86", "Feb-86"], inplace=True)

nibd = pd.concat([nibd_ati,nibd_can],axis=1,sort=False)
nibd = org_columns(nibd)

# %%
# Enterprise Level
# ev1 dá bem diferente de ev2
# ev1 = mve + nibd
# ev2 = mve.add(nibd, fill_value=0)
ev = mve.add(nibd, fill_value=0)

# %%
# Return on Capital (ROC)
# roc = ebit / (nwc + nfa)
roc = ebit.div(nwc.add(nfa,fill_value=0),fill_value=0)

# %%
# Earnings Yield
ey = ebit.div(ev, fill_value=0)

# %%
ey
# Out:
# ticker     AALR3  ABCB3  ABCB4     ABEV3  ABYA3     ACES3     ACES4  ACGU3  \
# Date
# Mar-86       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Jun-86       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Sep-86       NaN    NaN    NaN       NaN    NaN       NaN       NaN    NaN
# Dec-86       NaN    NaN    NaN  0.346678    NaN       NaN       NaN    NaN
# Mar-87       NaN    NaN    NaN  0.000000    NaN       NaN       NaN    NaN
# Jun-87       NaN    NaN    NaN  0.000000    NaN       NaN       NaN    NaN
# Sep-87       NaN    NaN    NaN  0.000000    NaN       NaN       NaN    NaN
# Dec-87       NaN    NaN    NaN -0.224333    NaN  0.000000  0.000000    NaN
# Mar-88       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Jun-88       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Sep-88       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Dec-88       NaN    NaN    NaN -0.052208    NaN  0.000000  0.000000    NaN
# Mar-89       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Jun-89       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Sep-89       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Dec-89       NaN    NaN    NaN  0.022460    NaN  0.000000  0.000000    NaN
# Mar-90       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Jun-90       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Sep-90       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Dec-90       NaN    NaN    NaN  0.983204    NaN  0.000000  0.000000    NaN
# Mar-91       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Jun-91       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Sep-91       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Dec-91       NaN    NaN    NaN  0.101297    NaN  0.000000  0.000000    NaN
# Mar-92       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Jun-92       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Sep-92       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Dec-92       NaN    NaN    NaN  0.141612    NaN -0.000295 -0.000295    NaN
# Mar-93       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# Jun-93       NaN    NaN    NaN  0.000000    NaN  0.000000  0.000000    NaN
# ...          ...    ...    ...       ...    ...       ...       ...    ...
# Jun-12       NaN    0.0    0.0  0.025695    NaN       NaN       NaN    NaN
# Sep-12       NaN    0.0    0.0  0.041130    NaN       NaN       NaN    NaN
# Dec-12       NaN    0.0    0.0  0.053714    NaN       NaN       NaN    NaN
# Mar-13       NaN    0.0    0.0  0.012004    NaN       NaN       NaN    NaN
# Jun-13       NaN    0.0    0.0  0.022643    NaN       NaN       NaN    NaN
# Sep-13       NaN    0.0    0.0  0.036086    NaN       NaN       NaN    NaN
# Dec-13       NaN    0.0    0.0  0.058627    NaN       NaN       NaN    NaN
# Mar-14       NaN    0.0    0.0  0.013519    NaN       NaN       NaN    NaN
# Jun-14       NaN    0.0    0.0  0.025876    NaN       NaN       NaN    NaN
# Sep-14       NaN    0.0    0.0  0.039432    NaN       NaN       NaN    NaN
# Dec-14       NaN    0.0    0.0  0.064135    NaN       NaN       NaN    NaN
# Mar-15       NaN    0.0    0.0  0.015446    NaN       NaN       NaN    NaN
# Jun-15       NaN    0.0    0.0  0.025505    NaN       NaN       NaN    NaN
# Sep-15       NaN    0.0    0.0  0.039508    NaN       NaN       NaN    NaN
# Dec-15  0.247215    0.0    0.0  0.069628    NaN       NaN       NaN    NaN
# Mar-16  0.049437    0.0    0.0  0.015017    NaN       NaN       NaN    NaN
# Jun-16  0.100109    0.0    0.0  0.025955    NaN       NaN       NaN    NaN
# Sep-16  0.154392    0.0    0.0  0.035177    NaN       NaN       NaN    NaN
# Dec-16  0.050637    0.0    0.0  0.067130    NaN       NaN       NaN    NaN
# Mar-17  0.011204    0.0    0.0  0.012314    NaN       NaN       NaN    NaN
# Jun-17  0.022574    0.0    0.0  0.023066    NaN       NaN       NaN    NaN
# Sep-17  0.038033    0.0    0.0  0.031199    NaN       NaN       NaN    NaN
# Dec-17  0.031166    0.0    0.0  0.050302    NaN       NaN       NaN    NaN
# Mar-18  0.012992    0.0    0.0  0.010036    NaN       NaN       NaN    NaN
# Jun-18  0.029108    0.0    0.0  0.026781    NaN       NaN       NaN    NaN
# Sep-18  0.049519    0.0    0.0  0.038357    NaN       NaN       NaN    NaN
# Dec-18  0.065258    0.0    0.0  0.073003    NaN       NaN       NaN    NaN
# Mar-19  0.015969    0.0    0.0  0.015777    NaN       NaN       NaN    NaN
# Jun-19  0.032009    0.0    0.0  0.027944    NaN       NaN       NaN    NaN
# Sep-19  0.000000    0.0    0.0  0.036775    NaN       NaN       NaN    NaN
#
# ticker     ADHM3     AEDU3    ...     WISA3  WISA4     WIZS3     WLMM3  \
# Date                          ...
# Mar-86       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Jun-86       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Sep-86       NaN       NaN    ...       NaN    NaN       NaN       NaN
# Dec-86       NaN       NaN    ...       NaN    NaN       NaN  0.253990
# Mar-87       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Jun-87       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Sep-87       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Dec-87       NaN       NaN    ...       NaN    NaN       NaN  1.279382
# Mar-88       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Jun-88       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Sep-88       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Dec-88       NaN       NaN    ...       NaN    NaN       NaN  0.228753
# Mar-89       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Jun-89       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Sep-89       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Dec-89       NaN       NaN    ...       NaN    NaN       NaN -0.269466
# Mar-90       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Jun-90       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Sep-90       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Dec-90       NaN       NaN    ...       NaN    NaN       NaN  0.945752
# Mar-91       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Jun-91       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Sep-91       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Dec-91       NaN       NaN    ...       NaN    NaN       NaN -0.150959
# Mar-92       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Jun-92       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Sep-92       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Dec-92       NaN       NaN    ...       NaN    NaN       NaN -0.076703
# Mar-93       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# Jun-93       NaN       NaN    ...       NaN    NaN       NaN  0.000000
# ...          ...       ...    ...       ...    ...       ...       ...
# Jun-12 -0.026499  0.000595    ...       0.0    0.0       NaN -0.027481
# Sep-12 -0.036566  0.000542    ...       NaN    NaN       NaN  0.014289
# Dec-12 -0.065483  0.000587    ...       NaN    NaN       NaN  0.165053
# Mar-13 -0.031132  0.000302    ...       NaN    NaN       NaN  0.010743
# Jun-13 -0.151465  0.000459    ...       NaN    NaN       NaN  0.046561
# Sep-13 -0.203516  0.000430    ...       NaN    NaN       NaN  0.086763
# Dec-13 -0.287314  0.000364    ...       NaN    NaN       NaN  0.101013
# Mar-14 -0.016132  0.000204    ...       NaN    NaN       NaN  0.019029
# Jun-14 -0.066805  0.000320    ...       NaN    NaN       NaN  0.022636
# Sep-14 -0.119702       NaN    ...       NaN    NaN       NaN  0.046874
# Dec-14 -0.390682       NaN    ...       NaN    NaN -1.226047  0.028152
# Mar-15 -0.025124       NaN    ...       NaN    NaN -0.383648 -0.015003
# Jun-15 -0.053307       NaN    ...       NaN    NaN  0.030113 -0.010392
# Sep-15 -0.154867       NaN    ...       NaN    NaN  0.080400 -0.009066
# Dec-15 -0.338411       NaN    ...       NaN    NaN  0.106083 -0.040067
# Mar-16 -0.057794       NaN    ...       NaN    NaN  0.026260 -0.060867
# Jun-16 -0.058660       NaN    ...       NaN    NaN  0.051290 -0.133278
# Sep-16 -0.120921       NaN    ...       NaN    NaN  0.069672 -0.182624
# Dec-16 -0.315373       NaN    ...       NaN    NaN  0.100183 -0.320575
# Mar-17 -0.086546       NaN    ...       NaN    NaN  0.024585 -0.009131
# Jun-17 -0.160363       NaN    ...       NaN    NaN  0.042306 -0.012743
# Sep-17 -0.207926       NaN    ...       NaN    NaN  0.073616 -0.001293
# Dec-17 -0.313476       NaN    ...       NaN    NaN  0.133864 -0.042936
# Mar-18 -0.159742       NaN    ...       NaN    NaN  0.030443  0.018905
# Jun-18 -0.056627       NaN    ...       NaN    NaN  0.097645  0.021164
# Sep-18 -0.137756       NaN    ...       NaN    NaN  0.168276  0.085845
# Dec-18 -0.239676       NaN    ...       NaN    NaN  0.281467  0.122102
# Mar-19 -0.142883       NaN    ...       NaN    NaN  0.069235  0.044955
# Jun-19  0.000000       NaN    ...       NaN    NaN  0.099199  0.120518
# Sep-19  0.000000       NaN    ...       NaN    NaN  0.000000  0.000000
#
# ticker     WLMM4         WMBY3         WMBY4     WWOW3     YDUQ3     ZIVI4
# Date
# Mar-86       NaN           NaN           NaN       NaN       NaN       NaN
# Jun-86       NaN           NaN           NaN       NaN       NaN       NaN
# Sep-86       NaN           NaN           NaN       NaN       NaN       NaN
# Dec-86  0.253990  0.000000e+00  0.000000e+00       NaN       NaN       NaN
# Mar-87  0.000000  0.000000e+00  0.000000e+00       NaN       NaN       NaN
# Jun-87  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Sep-87  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Dec-87  1.279382 -3.377197e-03 -3.377197e-03       NaN       NaN  0.000000
# Mar-88  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Jun-88  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Sep-88  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Dec-88  0.228753 -3.978980e-03 -3.978980e-03       NaN       NaN  0.000000
# Mar-89  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Jun-89  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Sep-89  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Dec-89 -0.269466  3.679436e-03  3.679436e-03       NaN       NaN  0.000967
# Mar-90  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Jun-90  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Sep-90  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Dec-90  0.945752  2.509100e-03  2.509100e-03       NaN       NaN  0.000978
# Mar-91  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Jun-91  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Sep-91  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Dec-91 -0.150959 -4.757393e-04 -4.757393e-04       NaN       NaN  0.000665
# Mar-92  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Jun-92  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Sep-92  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Dec-92 -0.076703 -1.474536e-03 -1.474536e-03       NaN       NaN -0.000268
# Mar-93  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# Jun-93  0.000000  0.000000e+00  0.000000e+00       NaN       NaN  0.000000
# ...          ...           ...           ...       ...       ...       ...
# Jun-12 -0.027481  1.212169e-04  1.212169e-04       NaN  0.032106       NaN
# Sep-12  0.014289  1.386220e-04  1.386220e-04       NaN  0.041262       NaN
# Dec-12  0.165053  1.782325e-04  1.782325e-04       NaN  0.041705       NaN
# Mar-13  0.010743  2.529104e-05  2.529104e-05       NaN  0.018298       NaN
# Jun-13  0.046561  4.988432e-05  4.988432e-05       NaN  0.027993       NaN
# Sep-13  0.086763  7.089733e-05  7.089733e-05       NaN  0.044581       NaN
# Dec-13  0.101013  1.388707e-04  1.388707e-04       NaN  0.044991       NaN
# Mar-14  0.019029 -1.176055e-05 -1.176055e-05       NaN  0.017646       NaN
# Jun-14  0.022636  1.527299e-05  1.527299e-05       NaN  0.023914       NaN
# Sep-14  0.046874  2.990517e-05  2.990517e-05       NaN  0.042283       NaN
# Dec-14  0.028152  1.666797e-05  1.666797e-05  0.000434  0.057920       NaN
# Mar-15 -0.015003 -2.408657e-05 -2.408657e-05 -0.000004  0.027116       NaN
# Jun-15 -0.010392  6.223714e-06  6.223714e-06  0.000059  0.048735       NaN
# Sep-15 -0.009066  4.103950e-06  4.103950e-06  0.000161  0.095646       NaN
# Dec-15 -0.040067  1.522711e-07  1.522711e-07  0.000445  0.110956       NaN
# Mar-16 -0.060867  1.442121e-05  1.442121e-05 -0.000040  0.036502       NaN
# Jun-16 -0.133278  2.273241e-05  2.273241e-05       NaN  0.026186       NaN
# Sep-16 -0.182624  5.331190e-05  5.331190e-05       NaN  0.051784       NaN
# Dec-16 -0.320575           NaN           NaN       NaN  0.083605       NaN
# Mar-17 -0.009131           NaN           NaN       NaN  0.029565       NaN
# Jun-17 -0.012743           NaN           NaN       NaN  0.072073       NaN
# Sep-17 -0.001293           NaN           NaN       NaN  0.055864       NaN
# Dec-17 -0.042936           NaN           NaN       NaN  0.053293       NaN
# Mar-18  0.018905           NaN           NaN       NaN  0.026153       NaN
# Jun-18  0.021164           NaN           NaN       NaN  0.067528       NaN
# Sep-18  0.085845           NaN           NaN       NaN  0.102675       NaN
# Dec-18  0.122102           NaN           NaN       NaN  0.108278       NaN
# Mar-19  0.044955           NaN           NaN       NaN  0.031843       NaN
# Jun-19  0.120518           NaN           NaN       NaN  0.054566       NaN
# Sep-19  0.000000           NaN           NaN       NaN  0.000000       NaN
#
# [135 rows x 999 columns]

# %%
# ey.loc["Mar-18"]
ey_ = ey.loc["Jun-19"]
roc_ = roc.loc["Mar-19"]

# %%
ey_.sort_values(ascending=False)
# Out:
# ticker
# FIGE3    179.666667
# FIGE4    179.666667
# CALI3     54.563107
# CALI4     54.563107
# CMSA4      1.098619
# CMSA3      1.098619
# MNPR3      0.624504
# STTR3      0.584374
# CEGR3      0.462138
# CORR3      0.453794
# CORR4      0.453794
# CEAB3      0.435736
# STKF3      0.311146
# VIVA3      0.291689
# RSUL4      0.265535
# RSUL3      0.265535
# GPAR3      0.238085
# INNT3      0.228256
# ODER3      0.194433
# ODER4      0.194433
# MNPR4      0.184226
# PTNT3      0.172129
# PTNT4      0.172129
# AGRO3      0.171524
# CNSY3      0.165935
# CEBR3      0.156307
# QUSW3      0.145402
# SMFT3      0.144353
# NUTR3      0.144056
# CASN4      0.140790
#             ...
# UOLL3           NaN
# UOLL4           NaN
# VAGV3           NaN
# VAGV4           NaN
# VASP3           NaN
# VCPA4           NaN
# VEMG4           NaN
# VGOR3           NaN
# VGOR4           NaN
# VIGR3           NaN
# VINE3           NaN
# VIVO3           NaN
# VIVO4           NaN
# VPSC3           NaN
# VPSC4           NaN
# VPTA3           NaN
# VPTA4           NaN
# VRLM4           NaN
# VSMA3           NaN
# VTEC4           NaN
# VVAX3           NaN
# VVAX4           NaN
# WET4            NaN
# WHMT3           NaN
# WISA3           NaN
# WISA4           NaN
# WMBY3           NaN
# WMBY4           NaN
# WWOW3           NaN
# ZIVI4           NaN
# Name: Jun-19, Length: 999, dtype: float64

# %%
# criar df com dictionary e um index e usar expressões lógicas
df1 = pd.DataFrame({'A': [12, 44, 17, 1],
                    'B': [4, 8, 100, -3],
                    'C': [47, 68, 52, 1],
                    'D': [0, 0, 0, 0]},
                    index=[0, 1, 2, 3])
df2 = pd.DataFrame({'A': [1, 2, 3, 4],
                    'B': [-10, 4, 5, 13],
                    'C': [12, 23, 10, 100],
                    'D': [1, 1, 1, 1]},
                    index=[0, 1, 2, 3])
df3 = pd.DataFrame({'A': [1, 2, 3, 4],
                    'B': [-10, np.nan, 5, 13],
                    'C': [np.nan, 23, 10, 100],
                    'D': [1, 1, 1, 1]},
                    index=[0, 1, 2, 3])
df4 = pd.DataFrame({'E': [10, 10, 10, 10],
                    'F': [10, 10, 10, 10]},
                    index=[0, 1, 2, 3])

# %%
df1+df3
# Out:
#     A      B      C  D
# 0  13   -6.0    NaN  1
# 1  46    NaN   91.0  1
# 2  20  105.0   62.0  1
# 3   5   10.0  101.0  1

# %%
print(
    df1.add(df3,fill_value=0)
)
print(
    df1+df3
)
# perceber como o fill value serve tanto para NAs no primeiro como no segundo dataframes
print(
    df3.add(df1,fill_value=0)
)
# Out:
#     A      B      C  D
# 0  13   -6.0   47.0  1
# 1  46    8.0   91.0  1
# 2  20  105.0   62.0  1
# 3   5   10.0  101.0  1
#     A      B      C  D
# 0  13   -6.0    NaN  1
# 1  46    NaN   91.0  1
# 2  20  105.0   62.0  1
# 3   5   10.0  101.0  1
#     A      B      C  D
# 0  13   -6.0   47.0  1
# 1  46    8.0   91.0  1
# 2  20  105.0   62.0  1
# 3   5   10.0  101.0  1

# %%
# concatena as colunas mas como não são coincidentes fica tudo NA
df1+df4
# concatena as colunas e cada coluna fica igual pois são não coincidentes
df1.add(df4, fill_value=0)
# Out:
#       A      B     C    D     E     F
# 0  12.0    4.0  47.0  0.0  10.0  10.0
# 1  44.0    8.0  68.0  0.0  10.0  10.0
# 2  17.0  100.0  52.0  0.0  10.0  10.0
# 3   1.0   -3.0   1.0  0.0  10.0  10.0

# %%
df1+df2+df3
# Out:
#     A      B      C  D
# 0  14  -16.0    NaN  2
# 1  48    NaN  114.0  2
# 2  23  110.0   72.0  2
# 3   9   23.0  201.0  2

# %%
df1.add(df2).sub(df3)
# Out:
#     A      B     C  D
# 0  12    4.0   NaN  0
# 1  44    NaN  68.0  0
# 2  17  100.0  52.0  0
# 3   1   -3.0   1.0  0

# %%
A = pd.DataFrame({'A':[10]})
B = pd.DataFrame({'A':[1]})
C = pd.DataFrame({'A':[5]})
